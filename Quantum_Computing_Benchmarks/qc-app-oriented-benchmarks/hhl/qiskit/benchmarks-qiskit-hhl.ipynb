# %% [markdown]
# ### QED-C Prototype Benchmarks - Qiskit Version
# The notebook contains a suite of prototype application benchmarks for the IBM Qiskit API.
# Configure and run the cell below with the desired execution settings.
# Then execute the remaining cells, each containing one prototype benchmark program.

# %%
pip install qiskit-ibmq-provider
# Out:
# Requirement already satisfied: qiskit-ibmq-provider in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (0.20.2)
# Requirement already satisfied: qiskit-terra>=0.18.0 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from qiskit-ibmq-provider) (0.25.3)
# Requirement already satisfied: requests>=2.19 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from qiskit-ibmq-provider) (2.31.0)
# Requirement already satisfied: requests-ntlm<=1.1.0 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from qiskit-ibmq-provider) (1.1.0)
# Requirement already satisfied: numpy<1.24 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from qiskit-ibmq-provider) (1.23.5)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from qiskit-ibmq-provider) (1.26.18)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from qiskit-ibmq-provider) (2.8.2)
# Requirement already satisfied: websocket-client>=1.5.1 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from qiskit-ibmq-provider) (1.6.4)
# Requirement already satisfied: websockets>=10.0 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from qiskit-ibmq-provider) (12.0)
# Requirement already satisfied: six>=1.5 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from python-dateutil>=2.8.0->qiskit-ibmq-provider) (1.16.0)
# Requirement already satisfied: rustworkx>=0.13.0 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (0.13.2)
# Requirement already satisfied: ply>=3.10 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (3.11)
# Requirement already satisfied: psutil>=5 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (5.9.6)
# Requirement already satisfied: scipy>=1.5 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (1.10.1)
# Requirement already satisfied: sympy>=1.3 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (1.12)
# Requirement already satisfied: dill>=0.3 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (0.3.7)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (5.1.0)
# Requirement already satisfied: typing-extensions in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider) (2023.7.22)
# Requirement already satisfied: ntlm-auth>=1.0.2 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from requests-ntlm<=1.1.0->qiskit-ibmq-provider) (1.5.0)
# Requirement already satisfied: cryptography>=1.3 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from requests-ntlm<=1.1.0->qiskit-ibmq-provider) (41.0.5)
# Requirement already satisfied: cffi>=1.12 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from cryptography>=1.3->requests-ntlm<=1.1.0->qiskit-ibmq-provider) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from stevedore>=3.0.0->qiskit-terra>=0.18.0->qiskit-ibmq-provider) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from sympy>=1.3->qiskit-terra>=0.18.0->qiskit-ibmq-provider) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\giris\anaconda3\envs\qiskit\lib\site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm<=1.1.0->qiskit-ibmq-provider) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
min_qubits=4
max_qubits=12
max_circuits=3
num_shots=1000

backend_id="qasm_simulator"
hub="ibm-q"; group="open"; project="main"
provider_backend = None
exec_options = None

# # ==========================
# # *** If using IBMQ hardware, run this once to authenticate
# from qiskit import IBMQ
# IBMQ.save_account('MY_API_TOKEN')

from qiskit_ibm_provider import IBMProvider
IBMProvider.save_account(token='9f77e2cae821d2b8fbb8aa9555078ce6ae3a9dd373c58b42cdf3faf267e64ae96bdbc3afcf9549fee34e78fb737b35410c1707d5cc0c582be44e8b36801d6dab', overwrite=True)


# # *** If you are part of an IBMQ group, set hub, group, and project name here
# hub="YOUR_HUB_NAME"; group="YOUR_GROUP_NAME"; project="YOUR_PROJECT_NAME"

# # *** This example shows how to specify an IBMQ backend using a known "backend_id"
# exec_options = { "optimization_level":3, "use_sessions":True, "resilience_level":1}
# backend_id="ibmq_belem"

# # ==========================
# # *** If using Azure Quantum, use this hub identifier and specify the desired backend_id
# # Identify your resources with env variables AZURE_QUANTUM_RESOURCE_ID and AZURE_QUANTUM_LOCATION
# hub="azure-quantum"; group="open"; project="QED-C App-Oriented Benchmarks - Qiskit Version"
# backend_id="<YOUR_BACKEND_NAME_HERE>"

# # ==========================
# The remaining examples create a provider instance and get a backend from it

# # An example using IonQ provider
# from qiskit_ionq import IonQProvider
# provider = IonQProvider()   # Be sure to set the QISKIT_IONQ_API_TOKEN environment variable
# provider_backend = provider.get_backend("ionq_qpu")
# backend_id="ionq_qpu"

# # An example using BlueQubit provider
# import sys
# sys.path.insert(1, "../..")
# import os, bluequbit, _common.executors.bluequbit_executor as bluequbit_executor
# provider_backend = bluequbit.init()
# backend_id="BlueQubit-CPU"
# exec_options = { "executor": bluequbit_executor.run, "device":'cpu' }

# # *** Here's an example of using a typical custom provider backend (e.g. AQT simulator)
# import os
# from qiskit_aqt_provider import AQTProvider
# provider = AQTProvider(os.environ.get('AQT_ACCESS_KEY'))    # get your key from environment
# provider_backend = provider.backends.aqt_qasm_simulator_noise_1
# backend_id="aqt_qasm_simulator_noise_1"

# Need this path set for imports used below
import sys
sys.path[1:1] = [ "../..", "../../_common" ]

# %%
# Custom optimization options can be specified in this cell (below is an example)

# # Example of pytket Transformer
# import _common.transformers.tket_optimiser as tket_optimiser
# exec_options.update({ "optimization_level": 0, "layout_method":'sabre', "routing_method":'sabre', "transformer": tket_optimiser.high_optimisation })

# # Define a custom noise model to be used during execution
# import _common.custom.custom_qiskit_noise_model as custom_qiskit_noise_model
# exec_options.update({ "noise_model": custom_qiskit_noise_model.my_noise_model() })

# # Example of mthree error mitigation
# import _common.postprocessors.mthree.mthree_em as mthree_em
# exec_options.update({ "postprocessor": mthree_em.get_mthree_handlers(backend_id, provider_backend) })

# %%
import sys
sys.path.insert(1, "hhl/qiskit")
import hhl_benchmark

hhl_benchmark.verbose=False

hhl_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=max_circuits, num_shots=num_shots,
                method=1, use_best_widths=True,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# HHL Benchmark Program - Qiskit
# ... execution starting at Nov 03, 2023 08:56:04 UTC
# ************
# Executing 3 circuits with 4 qubits, using 1 input qubits and 1 clock qubits
# ************
# Executing 3 circuits with 5 qubits, using 1 input qubits and 2 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 11, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 114, 0.307, 50.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.272, 4.276, 0.858 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.995, 0.948
#
# ************
# Executing 3 circuits with 6 qubits, using 1 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 13, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 212, 0.317, 100.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.547, 7.555, 1.289 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.984, 0.836
#
# ************
# Executing 3 circuits with 7 qubits, using 2 input qubits and 2 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 15, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 315, 0.323, 152.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.047, 8.625, 1.923 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.974, 0.738
#
# ************
# Executing 3 circuits with 8 qubits, using 2 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 13, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 272, 0.329, 176.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.533, 10.217, 2.059 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.802, 0.641
#
# ************
# Executing 3 circuits with 9 qubits, using 2 input qubits and 4 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 15, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 411, 0.331, 264.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 1.038, 11.608, 2.124 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.702, 0.458
#
# ************
# Executing 3 circuits with 10 qubits, using 3 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 17, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 556, 0.335, 356.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.781, 16.877, 3.195 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 0.67, 0.4
#
# ************
# Executing 3 circuits with 11 qubits, using 3 input qubits and 4 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 15, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 501, 0.336, 376.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 1.073, 29.064, 6.092 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.472, 0.318
#
# ************
# Executing 3 circuits with 12 qubits, using 3 input qubits and 5 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 11 qubit group = 17, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 11 qubit group = 684, 0.337, 504.0
# Average Creation, Elapsed, Execution Time for the 11 qubit group = 2.487, 41.536, 8.989 secs
# Average Transpiling, Validating, Running Times for group 11 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 11 qubit group = 0.397, 0.233
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 12 qubit group = 19, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 12 qubit group = 881, 0.341, 644.0
# Average Creation, Elapsed, Execution Time for the 12 qubit group = 3.326, 30.955, 14.208 secs
# Average Transpiling, Validating, Running Times for group 12 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 12 qubit group = 0.374, 0.219
#
# ... execution complete at Nov 03, 2023 08:59:00 UTC in 176.007 secs
#
# Sample Circuit:
#          ┌───┐ ░ ┌───────────┐ ░          ░                           ░        »
#   input: ┤ X ├─░─┤0          ├─░──────────░───────────────────────────░────────»
#          └───┘ ░ │           │ ░          ░                           ░        »
#  in_anc: ──────░─┤1          ├─░──────────░───────────────────────────░────────»
#          ┌───┐ ░ │  e^{0iAt} │ ░ ┌──────┐ ░      ┌──────────┐         ░ ┌─────┐»
#   clock: ┤ H ├─░─┤2          ├─░─┤ IQFT ├─░──────┤0         ├─────────░─┤ QFT ├»
#          └───┘ ░ │           │ ░ └──────┘ ░      │  INV_ROT │┌─┐      ░ └─────┘»
# ancilla: ──────░─┤3          ├─░──────────░──|0>─┤1         ├┤M├─|0>──░────────»
#                ░ └───────────┘ ░          ░      └──────────┘└╥┘      ░        »
#    c0: 1/═════════════════════════════════════════════════════╬════════════════»
#                                                               ║                »
#    c1: 1/═════════════════════════════════════════════════════╩════════════════»
#                                                               0                »
# «          ░ ┌────────────┐ ░       ░ ┌─┐
# «  input: ─░─┤0           ├─░───────░─┤M├
# «          ░ │            │ ░       ░ └╥┘
# « in_anc: ─░─┤1           ├─░───────░──╫─
# «          ░ │  e^{-0iAt} │ ░ ┌───┐ ░  ║
# «  clock: ─░─┤2           ├─░─┤ H ├─░──╫─
# «          ░ │            │ ░ └───┘ ░  ║
# «ancilla: ─░─┤3           ├─░───────░──╫─
# «          ░ └────────────┘ ░       ░  ║
# «   c0: 1/═════════════════════════════╩═
# «                                      0
# «   c1: 1/═══════════════════════════════
# «
#
# U Circuit =
#     ┌───┐            ┌───┐   ┌───────────┐┌──────────┐┌───────────┐     »
# q0: ┤ X ├────■───────┤ X ├───┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├──■──»
#     └───┘  ┌─┴─┐   ┌─┴───┴──┐└┬──────────┤└┬────────┬┘└───────────┘┌─┴─┐»
# q1: ───────┤ X ├───┤ Rz(-π) ├─┤ Ry(-π/2) ├─┤ Rz(-π) ├──────────────┤ X ├»
#            └───┘   └────────┘ └──────────┘ └────────┘              └───┘»
# q2: ──────■─────────────────────────────────────────────────────────────»
#     ┌───┐ │P(3π/2)   ┌───┐                                              »
# q3: ┤ X ├─■──────────┤ X ├──────────────────────────────────────────────»
#     └───┘            └───┘                                              »
# «     ┌──────────┐┌───────────┐                             ┌───┐┌───────────┐»
# «q0: ─┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────┤ X ├┤ Rz(-3π/2) ├»
# «    ┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐└─┬─┘└───┬───┬───┘»
# «q1: ┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├──■──────┤ X ├────»
# «    └───────────┘  └────────┘ └───┘└──────────┘└──────────┘         └───┘    »
# «q2: ─────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q3: ─────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «                      ┌───────────┐┌──────────┐┌───────────┐               »
# «q0: ──■────────────■──┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├────────────■──»
# «      │            │  └───┬───┬───┘└┬────────┬┘└┬──────────┤┌────────┐┌─┴─┐»
# «q1: ──■────────────■──────┤ X ├─────┤ Rz(-π) ├──┤ Ry(-π/2) ├┤ Rz(-π) ├┤ X ├»
# «      │            │      └───┘     └────────┘  └──────────┘└────────┘└───┘»
# «q2: ──┼───■────────┼───────────────────────────────────────────────────────»
# «    ┌─┴─┐ │P(-π) ┌─┴─┐                                                     »
# «q3: ┤ X ├─■──────┤ X ├─────────────────────────────────────────────────────»
# «    └───┘        └───┘                                                     »
# «     ┌──────────┐┌───────────┐                             ┌───┐┌───────────┐»
# «q0: ─┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────┤ X ├┤ Rz(-3π/2) ├»
# «    ┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐└─┬─┘└───────────┘»
# «q1: ┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├──■───────────────»
# «    └───────────┘  └────────┘ └───┘└──────────┘└──────────┘                  »
# «q2: ─────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q3: ─────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «    ┌───┐     ┌───┐
# «q0: ┤ X ├──■──┤ X ├
# «    └───┘┌─┴─┐└───┘
# «q1: ─────┤ X ├─────
# «         └───┘
# «q2: ───────────────
# «
# «q3: ───────────────
# «
#
# U^-1 Circuit =
#      ┌───┐             ┌───┐   ┌───────────┐┌──────────┐┌───────────┐     »
#  q8: ┤ X ├─────■───────┤ X ├───┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├──■──»
#      └───┘   ┌─┴─┐   ┌─┴───┴──┐└┬──────────┤└┬────────┬┘└───────────┘┌─┴─┐»
#  q9: ────────┤ X ├───┤ Rz(-π) ├─┤ Ry(-π/2) ├─┤ Rz(-π) ├──────────────┤ X ├»
#              └───┘   └────────┘ └──────────┘ └────────┘              └───┘»
# q10: ──────■──────────────────────────────────────────────────────────────»
#      ┌───┐ │P(-3π/2)   ┌───┐                                              »
# q11: ┤ X ├─■───────────┤ X ├──────────────────────────────────────────────»
#      └───┘             └───┘                                              »
# «      ┌──────────┐┌───────────┐                             ┌───┐┌───────────┐»
# « q8: ─┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────┤ X ├┤ Rz(-3π/2) ├»
# «     ┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐└─┬─┘└───┬───┬───┘»
# « q9: ┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├──■──────┤ X ├────»
# «     └───────────┘  └────────┘ └───┘└──────────┘└──────────┘         └───┘    »
# «q10: ─────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q11: ─────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «                      ┌───────────┐┌──────────┐┌───────────┐               »
# « q8: ──■───────────■──┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├────────────■──»
# «       │           │  └───┬───┬───┘└┬────────┬┘└┬──────────┤┌────────┐┌─┴─┐»
# « q9: ──■───────────■──────┤ X ├─────┤ Rz(-π) ├──┤ Ry(-π/2) ├┤ Rz(-π) ├┤ X ├»
# «       │           │      └───┘     └────────┘  └──────────┘└────────┘└───┘»
# «q10: ──┼───■───────┼───────────────────────────────────────────────────────»
# «     ┌─┴─┐ │P(π) ┌─┴─┐                                                     »
# «q11: ┤ X ├─■─────┤ X ├─────────────────────────────────────────────────────»
# «     └───┘       └───┘                                                     »
# «      ┌──────────┐┌───────────┐                             ┌───┐┌───────────┐»
# « q8: ─┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────┤ X ├┤ Rz(-3π/2) ├»
# «     ┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐└─┬─┘└───────────┘»
# « q9: ┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├──■───────────────»
# «     └───────────┘  └────────┘ └───┘└──────────┘└──────────┘                  »
# «q10: ─────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q11: ─────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «     ┌───┐     ┌───┐
# « q8: ┤ X ├──■──┤ X ├
# «     └───┘┌─┴─┐└───┘
# « q9: ─────┤ X ├─────
# «          └───┘
# «q10: ───────────────
# «
# «q11: ───────────────
# «
#
# QFT Circuit =
#     ┌───┐ ░
# q7: ┤ H ├─░─
#     └───┘ ░
#
# Inverse QFT Circuit =
#     ┌───┐ ░
# q4: ┤ H ├─░─
#     └───┘ ░
#
# Hamiltonian Phase Estimation Circuit =
#   ... too large!
#
# Controlled Rotation Circuit =
#
# q5: ─────────────────■────────────────────■──
#     ┌─────────────┐┌─┴─┐┌──────────────┐┌─┴─┐
# q6: ┤ Ry(0.77628) ├┤ X ├┤ Ry(-0.27092) ├┤ X ├
#     └─────────────┘└───┘└──────────────┘└───┘

# %%
import sys
sys.path.insert(1, "hhl/qiskit")
import hhl_benchmark

hhl_benchmark.verbose=False

# This run2 method allows you to specify an arbitrary range of input and clock qubit sizes

min_input_qubits=1
max_input_qubits=3
min_clock_qubits=2
max_clock_qubits=3

hhl_benchmark.run2(min_input_qubits=min_input_qubits, max_input_qubits=max_input_qubits,
                 min_clock_qubits=min_clock_qubits, max_clock_qubits=max_clock_qubits,
                 max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# HHL Benchmark Program - Qiskit
# ... execution starting at Nov 03, 2023 08:59:23 UTC
# ************
# Executing 3 circuits with 5 qubits, using 1 input qubits and 2 clock qubits
# ************
# Executing 3 circuits with 6 qubits, using 1 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 13, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 212, 0.317, 100.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.369, 5.411, 1.045 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.983, 0.831
#
# ************
# Executing 3 circuits with 7 qubits, using 2 input qubits and 2 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 15, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 315, 0.323, 152.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.466, 6.977, 1.283 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.967, 0.665
#
# ************
# Executing 3 circuits with 8 qubits, using 2 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 13, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 274, 0.33, 176.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.461, 9.122, 1.511 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.842, 0.712
#
# ************
# Executing 3 circuits with 9 qubits, using 3 input qubits and 2 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 15, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 411, 0.331, 264.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.62, 12.354, 2.186 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.668, 0.396
#
# ************
# Executing 3 circuits with 10 qubits, using 3 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 9 qubit group = 13, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 9 qubit group = 338, 0.333, 252.0
# Average Creation, Elapsed, Execution Time for the 9 qubit group = 0.783, 18.377, 3.102 secs
# Average Transpiling, Validating, Running Times for group 9 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 9 qubit group = 0.353, 0.21
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 10 qubit group = 15, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 10 qubit group = 507, 0.335, 376.0
# Average Creation, Elapsed, Execution Time for the 10 qubit group = 1.605, 13.22, 4.999 secs
# Average Transpiling, Validating, Running Times for group 10 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 10 qubit group = 0.494, 0.347
#
# ... execution complete at Nov 03, 2023 09:00:35 UTC in 72.11 secs
#
# Sample Circuit:
#          ┌───┐ ░ ┌───────────┐┌───────────┐ ░           ░                     »
#   input: ┤ X ├─░─┤0          ├┤0          ├─░───────────░─────────────────────»
#          └───┘ ░ │           ││           │ ░           ░                     »
#  in_anc: ──────░─┤1          ├┤1          ├─░───────────░─────────────────────»
#          ┌───┐ ░ │           ││           │ ░ ┌───────┐ ░      ┌──────────┐   »
# clock_0: ┤ H ├─░─┤2 e^{0iAt} ├┤  e^{1iAt} ├─░─┤0      ├─░──────┤0         ├───»
#          ├───┤ ░ │           ││           │ ░ │  IQFT │ ░      │          │   »
# clock_1: ┤ H ├─░─┤           ├┤2          ├─░─┤1      ├─░──────┤1 INV_ROT ├───»
#          └───┘ ░ │           ││           │ ░ └───────┘ ░      │          │┌─┐»
# ancilla: ──────░─┤3          ├┤3          ├─░───────────░──|0>─┤2         ├┤M├»
#                ░ └───────────┘└───────────┘ ░           ░      └──────────┘└╥┘»
#   c54: 1/═══════════════════════════════════════════════════════════════════╬═»
#                                                                             ║ »
#   c55: 1/═══════════════════════════════════════════════════════════════════╩═»
#                                                                             0 »
# «               ░          ░ ┌────────────┐┌────────────┐ ░       ░ ┌─┐
# «  input: ──────░──────────░─┤0           ├┤0           ├─░───────░─┤M├
# «               ░          ░ │            ││            │ ░       ░ └╥┘
# « in_anc: ──────░──────────░─┤1           ├┤1           ├─░───────░──╫─
# «               ░ ┌──────┐ ░ │            ││            │ ░ ┌───┐ ░  ║
# «clock_0: ──────░─┤0     ├─░─┤  e^{-1iAt} ├┤2 e^{-0iAt} ├─░─┤ H ├─░──╫─
# «               ░ │  QFT │ ░ │            ││            │ ░ ├───┤ ░  ║
# «clock_1: ──────░─┤1     ├─░─┤2           ├┤            ├─░─┤ H ├─░──╫─
# «               ░ └──────┘ ░ │            ││            │ ░ └───┘ ░  ║
# «ancilla: ─|0>──░──────────░─┤3           ├┤3           ├─░───────░──╫─
# «               ░          ░ └────────────┘└────────────┘ ░       ░  ║
# «  c54: 1/═══════════════════════════════════════════════════════════╩═
# «                                                                    0
# «  c55: 1/═════════════════════════════════════════════════════════════
# «
#
# U Circuit =
#        ┌───┐            ┌───┐   ┌───────────┐┌──────────┐┌───────────┐     »
# q1674: ┤ X ├────■───────┤ X ├───┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├──■──»
#        └───┘  ┌─┴─┐   ┌─┴───┴──┐└┬──────────┤└┬────────┬┘└───────────┘┌─┴─┐»
# q1675: ───────┤ X ├───┤ Rz(-π) ├─┤ Ry(-π/2) ├─┤ Rz(-π) ├──────────────┤ X ├»
#               └───┘   └────────┘ └──────────┘ └────────┘              └───┘»
# q1676: ──────■─────────────────────────────────────────────────────────────»
#        ┌───┐ │P(3π/2)   ┌───┐                                              »
# q1677: ┤ X ├─■──────────┤ X ├──────────────────────────────────────────────»
#        └───┘            └───┘                                              »
# «        ┌──────────┐┌───────────┐                             ┌───┐»
# «q1674: ─┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────┤ X ├»
# «       ┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐└─┬─┘»
# «q1675: ┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├──■──»
# «       └───────────┘  └────────┘ └───┘└──────────┘└──────────┘     »
# «q1676: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «q1677: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «       ┌───────────┐                  ┌───────────┐┌──────────┐┌───────────┐»
# «q1674: ┤ Rz(-3π/2) ├──■────────────■──┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├»
# «       └───┬───┬───┘  │            │  └───┬───┬───┘└┬────────┬┘└┬──────────┤»
# «q1675: ────┤ X ├──────■────────────■──────┤ X ├─────┤ Rz(-π) ├──┤ Ry(-π/2) ├»
# «           └───┘      │            │      └───┘     └────────┘  └──────────┘»
# «q1676: ───────────────┼───■────────┼────────────────────────────────────────»
# «                    ┌─┴─┐ │P(-π) ┌─┴─┐                                      »
# «q1677: ─────────────┤ X ├─■──────┤ X ├──────────────────────────────────────»
# «                    └───┘        └───┘                                      »
# «                       ┌──────────┐┌───────────┐                             »
# «q1674: ────────────■───┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────»
# «       ┌────────┐┌─┴─┐┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐»
# «q1675: ┤ Rz(-π) ├┤ X ├┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├»
# «       └────────┘└───┘└───────────┘  └────────┘ └───┘└──────────┘└──────────┘»
# «q1676: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q1677: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «       ┌───┐┌───────────┐┌───┐     ┌───┐
# «q1674: ┤ X ├┤ Rz(-3π/2) ├┤ X ├──■──┤ X ├
# «       └─┬─┘└───────────┘└───┘┌─┴─┐└───┘
# «q1675: ──■────────────────────┤ X ├─────
# «                              └───┘
# «q1676: ─────────────────────────────────
# «
# «q1677: ─────────────────────────────────
# «
#
# U^-1 Circuit =
#        ┌───┐           ┌───┐   ┌───────────┐┌──────────┐┌───────────┐     »
# q1686: ┤ X ├────■──────┤ X ├───┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├──■──»
#        └───┘  ┌─┴─┐  ┌─┴───┴──┐└┬──────────┤└┬────────┬┘└───────────┘┌─┴─┐»
# q1687: ───────┤ X ├──┤ Rz(-π) ├─┤ Ry(-π/2) ├─┤ Rz(-π) ├──────────────┤ X ├»
#               └───┘  └────────┘ └──────────┘ └────────┘              └───┘»
# q1688: ──────■────────────────────────────────────────────────────────────»
#        ┌───┐ │P(-3π)   ┌───┐                                              »
# q1689: ┤ X ├─■─────────┤ X ├──────────────────────────────────────────────»
#        └───┘           └───┘                                              »
# «        ┌──────────┐┌───────────┐                             ┌───┐»
# «q1686: ─┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────┤ X ├»
# «       ┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐└─┬─┘»
# «q1687: ┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├──■──»
# «       └───────────┘  └────────┘ └───┘└──────────┘└──────────┘     »
# «q1688: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «q1689: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «       ┌───────────┐                  ┌───────────┐┌──────────┐┌───────────┐»
# «q1686: ┤ Rz(-3π/2) ├──■────────────■──┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├»
# «       └───┬───┬───┘  │            │  └───┬───┬───┘└┬────────┬┘└┬──────────┤»
# «q1687: ────┤ X ├──────■────────────■──────┤ X ├─────┤ Rz(-π) ├──┤ Ry(-π/2) ├»
# «           └───┘      │            │      └───┘     └────────┘  └──────────┘»
# «q1688: ───────────────┼───■────────┼────────────────────────────────────────»
# «                    ┌─┴─┐ │P(2π) ┌─┴─┐                                      »
# «q1689: ─────────────┤ X ├─■──────┤ X ├──────────────────────────────────────»
# «                    └───┘        └───┘                                      »
# «                       ┌──────────┐┌───────────┐                             »
# «q1686: ────────────■───┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────»
# «       ┌────────┐┌─┴─┐┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐»
# «q1687: ┤ Rz(-π) ├┤ X ├┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├»
# «       └────────┘└───┘└───────────┘  └────────┘ └───┘└──────────┘└──────────┘»
# «q1688: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q1689: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «       ┌───┐┌───────────┐┌───┐     ┌───┐
# «q1686: ┤ X ├┤ Rz(-3π/2) ├┤ X ├──■──┤ X ├
# «       └─┬─┘└───────────┘└───┘┌─┴─┐└───┘
# «q1687: ──■────────────────────┤ X ├─────
# «                              └───┘
# «q1688: ─────────────────────────────────
# «
# «q1689: ─────────────────────────────────
# «
#
# QFT Circuit =
#          ┌───┐               ░
# q1685_0: ┤ H ├─■─────────────░─
#          └───┘ │P(π/2) ┌───┐ ░
# q1685_1: ──────■───────┤ H ├─░─
#                        └───┘ ░
#
# Inverse QFT Circuit =
#                         ┌───┐ ░
# q1682_0: ──────■────────┤ H ├─░─
#          ┌───┐ │P(-π/2) └───┘ ░
# q1682_1: ┤ H ├─■──────────────░─
#          └───┘                ░
#
# Hamiltonian Phase Estimation Circuit =
#   ... too large!
#
# Controlled Rotation Circuit =
#                                                                       »
# q1683_0: ─────────────────────────────────────■───────────────────────»
#                                               │                       »
# q1683_1: ────────────────■────────────────────┼────────────────────■──»
#          ┌────────────┐┌─┴─┐┌──────────────┐┌─┴─┐┌──────────────┐┌─┴─┐»
#   q1684: ┤ Ry(1.3435) ├┤ X ├┤ Ry(-0.56718) ├┤ X ├┤ Ry(-0.75094) ├┤ X ├»
#          └────────────┘└───┘└──────────────┘└───┘└──────────────┘└───┘»
# «
# «q1683_0: ─────────────────■──
# «                          │
# «q1683_1: ─────────────────┼──
# «         ┌─────────────┐┌─┴─┐
# «  q1684: ┤ Ry(0.48002) ├┤ X ├
# «         └─────────────┘└───┘

# %%
from qiskit.visualization import plot_histogram

# Get the counts, the frequency of each answer
counts = hhl_benchmark.saved_result.get_counts()

# Display the results
plot_histogram(counts)

# %%
hhl_benchmark.QC_.draw('mpl',scale=1)
#print(circuit)
