# %% [markdown]
# ### QED-C Application-Oriented Benchmarks - Qiskit Version
# The notebook contains a suite of application-oriented benchmarks for the Qiskit API.
# Configure and run the cell below with the desired execution settings.
# Then execute the remaining cells, each containing one benchmark program.

# %%
min_qubits=2
max_qubits=8
skip_qubits=1
max_circuits=3
num_shots=1000

backend_id="qasm_simulator"
#backend_id="statevector_simulator"

hub="ibm-q"; group="open"; project="main"
provider_backend = None
exec_options = {}

# # ==========================
# # *** If using IBMQ hardware, run this once to authenticate
# from qiskit import IBMQ
# IBMQ.save_account('YOUR_API_TOKEN_HERE')

# # *** If you are part of an IBMQ group, set hub, group, and project name here
# hub="YOUR_HUB_NAME"; group="YOUR_GROUP_NAME"; project="YOUR_PROJECT_NAME"

# # *** This example shows how to specify an IBMQ backend using a known "backend_id"
# exec_options = { "optimization_level":3, "use_sessions":True, "resilience_level":1}
# backend_id="ibmq_belem"

# # ==========================
# # *** If using Azure Quantum, use this hub identifier and specify the desired backend_id
# # Identify your resources with env variables AZURE_QUANTUM_RESOURCE_ID and AZURE_QUANTUM_LOCATION
# hub="azure-quantum"; group="open"; project="QED-C App-Oriented Benchmarks - Qiskit Version"
# backend_id="<YOUR_BACKEND_NAME_HERE>"

# # ==========================
# The remaining examples illustrate other backend execution options

# # An example using IonQ provider
# from qiskit_ionq import IonQProvider
# provider = IonQProvider()   # Be sure to set the QISKIT_IONQ_API_TOKEN environment variable
# provider_backend = provider.get_backend("ionq_qpu")
# backend_id="ionq_qpu"

# # An example using BlueQubit provider
# import os, bluequbit, _common.executors.bluequbit_executor as bluequbit_executor
# provider_backend = bluequbit.init()
# backend_id="BlueQubit-CPU"

# # An example using a typical custom provider backend (e.g. AQT simulator)
# import os
# from qiskit_aqt_provider import AQTProvider
# provider = AQTProvider(os.environ.get('AQT_ACCESS_KEY'))    # get your key from environment
# provider_backend = provider.backends.aqt_qasm_simulator_noise_1
# backend_id="aqt_qasm_simulator_noise_1"

# # Fire Opal can be used to manage executions on other backends, as illustrated here
# import _common.executors.fire_opal_executor as fire_opal_executor
# from _common.executors.fire_opal_executor import FireOpalBackend
# ibm_backend_id = "ibmq_jakarta"
# backend_id = f"fire_opal_{ibm_backend_id}"
# provider_backend = FireOpalBackend(ibm_backend_id=ibm_backend_id, hub=hub, group=group, project=project, token=token)
# exec_options = {"executor": fire_opal_executor.run}

# %%
# Custom optimization options can be specified in this cell (below is an example)

# # Example of pytket Transformer
# import _common.transformers.tket_optimiser as tket_optimiser
# exec_options.update({ "optimization_level": 0, "layout_method":'sabre', "routing_method":'sabre', "transformer": tket_optimiser.high_optimisation })

# # Define a custom noise model to be used during execution
# import _common.custom.custom_qiskit_noise_model as custom_qiskit_noise_model
# exec_options.update({ "noise_model": custom_qiskit_noise_model.my_noise_model() })

# # Example of mthree error mitigation
# import _common.postprocessors.mthree.mthree_em as mthree_em
# exec_options.update({ "postprocessor": mthree_em.get_mthree_handlers(backend_id, provider_backend) })

# %% [markdown]
# ### Deutsch-Jozsa

# %%
import sys
sys.path.insert(1, "deutsch-jozsa/qiskit")
import dj_benchmark
dj_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Deutsch-Jozsa Benchmark Program - Qiskit
# ... execution starting at Nov 02, 2023 17:00:18 UTC
# ************
# Executing [2] circuits with num_qubits = 3
# ************
# Executing [2] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 7, 0.083
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 7, 0.071, 1.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.021, 0.628, 0.291 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.5, 0.499
#
# ************
# Executing [2] circuits with num_qubits = 5
# ************
# Executing [2] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 8, 0.088
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 8, 0.071, 1.5
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.001, 1.181, 0.214 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.497, 0.497
#
# ************
# Executing [2] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 8, 0.1
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 8, 0.077, 2.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.0, 1.381, 0.282 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.499, 0.498
#
# ************
# Executing [2] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 8, 0.1
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 8, 0.076, 2.5
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.0, 1.211, 0.283 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.498, 0.498
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 10, 0.107
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 10, 0.079, 3.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.008, 1.157, 0.319 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.495, 0.494
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 10, 0.106
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 10, 0.078, 3.5
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 0.717, 0.326 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.496, 0.496
#
# ... execution complete at Nov 02, 2023 17:00:27 UTC in 9.251 secs
#
# Sample Circuit:
#        ┌───┐      ░ ┌─────┐ ░ ┌───┐      ░ ┌─┐
# q97_0: ┤ H ├──────░─┤0    ├─░─┤ H ├──────░─┤M├────────────
#        ├───┤      ░ │     │ ░ ├───┤      ░ └╥┘┌─┐
# q97_1: ┤ H ├──────░─┤1    ├─░─┤ H ├──────░──╫─┤M├─────────
#        ├───┤      ░ │     │ ░ ├───┤      ░  ║ └╥┘┌─┐
# q97_2: ┤ H ├──────░─┤2    ├─░─┤ H ├──────░──╫──╫─┤M├──────
#        ├───┤      ░ │  Uf │ ░ ├───┤      ░  ║  ║ └╥┘┌─┐
# q97_3: ┤ H ├──────░─┤3    ├─░─┤ H ├──────░──╫──╫──╫─┤M├───
#        ├───┤      ░ │     │ ░ ├───┤      ░  ║  ║  ║ └╥┘┌─┐
# q97_4: ┤ H ├──────░─┤4    ├─░─┤ H ├──────░──╫──╫──╫──╫─┤M├
#        ├───┤┌───┐ ░ │     │ ░ ├───┤┌───┐ ░  ║  ║  ║  ║ └╥┘
# q97_5: ┤ X ├┤ H ├─░─┤5    ├─░─┤ H ├┤ X ├─░──╫──╫──╫──╫──╫─
#        └───┘└───┘ ░ └─────┘ ░ └───┘└───┘ ░  ║  ║  ║  ║  ║
#  c7: 5/═════════════════════════════════════╩══╩══╩══╩══╩═
#                                             0  1  2  3  4
#
# Constant Oracle 'Uf' =
#
# q_0:
#
# q_1:
#
# q_2:
#
# q_3:
#
# q_4:
#
# q_5:
#
#
# Balanced Oracle 'Uf' =
#      ┌───┐ ░                           ░ ┌───┐
# q_0: ┤ X ├─░───■───────────────────────░─┤ X ├
#      └───┘ ░   │                       ░ └───┘
# q_1: ──────░───┼────■──────────────────░──────
#      ┌───┐ ░   │    │                  ░ ┌───┐
# q_2: ┤ X ├─░───┼────┼────■─────────────░─┤ X ├
#      └───┘ ░   │    │    │             ░ └───┘
# q_3: ──────░───┼────┼────┼────■────────░──────
#      ┌───┐ ░   │    │    │    │        ░ ┌───┐
# q_4: ┤ X ├─░───┼────┼────┼────┼────■───░─┤ X ├
#      └───┘ ░ ┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐┌─┴─┐ ░ └───┘
# q_5: ──────░─┤ X ├┤ X ├┤ X ├┤ X ├┤ X ├─░──────
#            ░ └───┘└───┘└───┘└───┘└───┘ ░

# %% [markdown]
# ### Bernstein-Vazirani - Method 1

# %%
import sys
sys.path.insert(1, "bernstein-vazirani/qiskit")
import bv_benchmark
bv_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Bernstein-Vazirani (1) Benchmark Program - Qiskit
# ... execution starting at Nov 02, 2023 17:00:37 UTC
# ************
# Executing [3] circuits with num_qubits = 3
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 6, 0.141
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 6, 0.116, 1.333
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.0, 0.723, 0.142 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.004, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 6, 0.061
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 6, 0.044, 0.667
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.976, 0.162 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.334, 0.331
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 7, 0.121
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 7, 0.084, 1.667
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.0, 1.016, 0.188 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.003, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 8, 0.175
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 8, 0.119, 3.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.0, 1.058, 0.23 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.0, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 9, 0.183
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 9, 0.122, 3.667
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.0, 1.238, 0.261 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.002, 0.0
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 8, 0.153
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 8, 0.099, 3.333
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 0.698, 0.259 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.001, 0.0
#
# ... execution complete at Nov 02, 2023 17:00:44 UTC in 6.503 secs
#
# Sample Circuit:
#         ┌───┐      ░ ┌─────┐ ░ ┌───┐      ░ ┌─┐
# q337_0: ┤ H ├──────░─┤0    ├─░─┤ H ├──────░─┤M├────────────
#         ├───┤      ░ │     │ ░ ├───┤      ░ └╥┘┌─┐
# q337_1: ┤ H ├──────░─┤1    ├─░─┤ H ├──────░──╫─┤M├─────────
#         ├───┤      ░ │     │ ░ ├───┤      ░  ║ └╥┘┌─┐
# q337_2: ┤ H ├──────░─┤2    ├─░─┤ H ├──────░──╫──╫─┤M├──────
#         ├───┤      ░ │  Uf │ ░ ├───┤      ░  ║  ║ └╥┘┌─┐
# q337_3: ┤ H ├──────░─┤3    ├─░─┤ H ├──────░──╫──╫──╫─┤M├───
#         ├───┤      ░ │     │ ░ ├───┤      ░  ║  ║  ║ └╥┘┌─┐
# q337_4: ┤ H ├──────░─┤4    ├─░─┤ H ├──────░──╫──╫──╫──╫─┤M├
#         ├───┤┌───┐ ░ │     │ ░ ├───┤┌───┐ ░  ║  ║  ║  ║ └╥┘
# q337_5: ┤ X ├┤ H ├─░─┤5    ├─░─┤ H ├┤ X ├─░──╫──╫──╫──╫──╫─
#         └───┘└───┘ ░ └─────┘ ░ └───┘└───┘ ░  ║  ║  ║  ║  ║
#  c23: 5/═════════════════════════════════════╩══╩══╩══╩══╩═
#                                              0  1  2  3  4
#
# Quantum Oracle 'Uf' =
#
# q338_0: ──────────
#
# q338_1: ──────────
#
# q338_2: ──■───────
#           │
# q338_3: ──┼────■──
#           │    │
# q338_4: ──┼────┼──
#         ┌─┴─┐┌─┴─┐
# q338_5: ┤ X ├┤ X ├
#         └───┘└───┘

# %% [markdown]
# ### Bernstein-Vazirani - Method 2

# %%
import sys
sys.path.insert(1, "bernstein-vazirani/qiskit")
import bv_benchmark
bv_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Bernstein-Vazirani (2) Benchmark Program - Qiskit
# ... execution starting at Nov 02, 2023 17:00:49 UTC
# ************
# Executing [3] circuits with num_qubits = 3
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 9, 0.114
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 10, 0.093, 1.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.001, 0.551, 0.082 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.335, 0.332
#
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 12, 0.121
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 14, 0.095, 1.333
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 0.868, 0.091 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.33, 0.328
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 18, 0.185
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 22, 0.142, 2.667
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.0, 0.91, 0.131 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.003, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 17, 0.114
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 19, 0.089, 1.667
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.0, 0.948, 0.11 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.326, 0.325
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 20, 0.127
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 23, 0.105, 2.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.0, 1.104, 0.128 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.004, 0.0
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 27, 0.183
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 33, 0.139, 3.667
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 0.774, 0.18 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.001, 0.0
#
# ... execution complete at Nov 02, 2023 17:00:55 UTC in 5.819 secs
#
# Sample Circuit:
#                    ░ ┌─┐     ┌─┐     ┌───┐     ┌───┐┌─┐     ┌───┐     ┌───┐┌─┐»
# q635_0: ───────────░─┤M├─|0>─┤M├─|0>─┤ H ├──■──┤ H ├┤M├─|0>─┤ H ├──■──┤ H ├┤M├»
#         ┌───┐┌───┐ ░ └╥┘     └╥┘     └───┘┌─┴─┐└───┘└╥┘     └───┘┌─┴─┐└───┘└╥┘»
# q635_1: ┤ X ├┤ H ├─░──╫───────╫───────────┤ X ├──────╫───────────┤ X ├──────╫─»
#         └───┘└───┘ ░  ║       ║           └───┘      ║           └───┘      ║ »
#  c41: 5/══════════════╩═══════╩══════════════════════╩══════════════════════╩═»
#                       0       1                      2                      3 »
# «             ┌─┐
# «q635_0: ─|0>─┤M├─|0>─
# «             └╥┘
# «q635_1: ──────╫──────
# «              ║
# « c41: 5/══════╩══════
# «              4

# %% [markdown]
# ### Hidden Shift

# %%
import sys
sys.path.insert(1, "hidden-shift/qiskit")
import hs_benchmark
hs_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Hidden Shift Benchmark Program - Qiskit
# ... execution starting at Nov 02, 2023 17:01:01 UTC
# ************
# Executing [3] circuits with num_qubits = 2
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 8, 0.189
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 16, 0.091, 2.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.001, 0.888, 0.152 secs
# Average Transpiling, Validating, Running Times for group 2 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0.002, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 8, 0.215
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 16, 0.094, 4.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.083, 1.341, 0.256 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.0, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 8, 0.192
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 17, 0.09, 6.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.001, 1.817, 0.369 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.0, 0.0
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 8, 0.204
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 17, 0.09, 8.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.0, 1.286, 0.565 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.0, 0.0
#
# ... execution complete at Nov 02, 2023 17:01:07 UTC in 6.174 secs
#
# Sample Circuit:
#         ┌───┐ ░ ┌─────┐ ░ ┌───┐ ░ ┌─────┐ ░ ┌───┐ ░ ┌─┐
# q906_0: ┤ H ├─░─┤0    ├─░─┤ H ├─░─┤0    ├─░─┤ H ├─░─┤M├───────────────
#         ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░ └╥┘┌─┐
# q906_1: ┤ H ├─░─┤1    ├─░─┤ H ├─░─┤1    ├─░─┤ H ├─░──╫─┤M├────────────
#         ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░  ║ └╥┘┌─┐
# q906_2: ┤ H ├─░─┤2    ├─░─┤ H ├─░─┤2    ├─░─┤ H ├─░──╫──╫─┤M├─────────
#         ├───┤ ░ │  Uf │ ░ ├───┤ ░ │  Ug │ ░ ├───┤ ░  ║  ║ └╥┘┌─┐
# q906_3: ┤ H ├─░─┤3    ├─░─┤ H ├─░─┤3    ├─░─┤ H ├─░──╫──╫──╫─┤M├──────
#         ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░  ║  ║  ║ └╥┘┌─┐
# q906_4: ┤ H ├─░─┤4    ├─░─┤ H ├─░─┤4    ├─░─┤ H ├─░──╫──╫──╫──╫─┤M├───
#         ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░  ║  ║  ║  ║ └╥┘┌─┐
# q906_5: ┤ H ├─░─┤5    ├─░─┤ H ├─░─┤5    ├─░─┤ H ├─░──╫──╫──╫──╫──╫─┤M├
#         └───┘ ░ └─────┘ ░ └───┘ ░ └─────┘ ░ └───┘ ░  ║  ║  ║  ║  ║ └╥┘
#  c56: 6/═════════════════════════════════════════════╩══╩══╩══╩══╩══╩═
#                                                      0  1  2  3  4  5
#
# Quantum Oracle 'Uf' =
#
# q907_0: ──────■──────
#         ┌───┐ │ ┌───┐
# q907_1: ┤ X ├─■─┤ X ├
#         ├───┤   ├───┤
# q907_2: ┤ X ├─■─┤ X ├
#         └───┘ │ └───┘
# q907_3: ──────■──────
#         ┌───┐   ┌───┐
# q907_4: ┤ X ├─■─┤ X ├
#         └───┘ │ └───┘
# q907_5: ──────■──────
#
#
# Quantum Oracle 'Ug' =
#
# q908_0: ─■─
#          │
# q908_1: ─■─
#
# q908_2: ─■─
#          │
# q908_3: ─■─
#
# q908_4: ─■─
#          │
# q908_5: ─■─

# %% [markdown]
# ### Quantum Fourier Transform - Method 1

# %%
import sys
sys.path.insert(1, "quantum-fourier-transform/qiskit")
import qft_benchmark
qft_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Quantum Fourier Transform (1) Benchmark Program - Qiskit
# ... execution starting at Nov 02, 2023 17:01:12 UTC
# ************
# Executing [3] circuits with num_qubits = 2
# ... number of gates, depth = 11, 8
# ************
# Executing [3] circuits with num_qubits = 3
# ... number of gates, depth = 19, 14
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 9, 0.215
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 18, 0.207, 4.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.001, 0.619, 0.074 secs
# Average Transpiling, Validating, Running Times for group 2 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0.983, 0.977
#
# ************
# Executing [3] circuits with num_qubits = 4
# ... number of gates, depth = 29, 22
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 15, 0.368
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 35, 0.298, 12.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.0, 1.062, 0.02 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.955, 0.948
#
# ************
# Executing [3] circuits with num_qubits = 5
# ... number of gates, depth = 42, 32
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 23, 0.474
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 58, 0.346, 24.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.005, 1.302, 0.024 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.907, 0.901
#
# ************
# Executing [3] circuits with num_qubits = 6
# ... number of gates, depth = 58, 44
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 33, 0.531
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 87, 0.372, 40.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.008, 1.355, 0.032 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.841, 0.836
#
# ************
# Executing [3] circuits with num_qubits = 7
# ... number of gates, depth = 74, 58
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 45, 0.577
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 122, 0.39, 60.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.005, 1.488, 0.058 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.783, 0.779
#
# ************
# Executing [3] circuits with num_qubits = 8
# ... number of gates, depth = 92, 74
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 59, 0.64
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 163, 0.408, 84.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.016, 1.794, 0.121 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.703, 0.701
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 75, 0.664
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 210, 0.417, 112.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.01, 1.202, 0.132 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.638, 0.637
#
# ... execution complete at Nov 02, 2023 17:01:22 UTC in 9.909 secs
#
# Sample Circuit:
#                ░ ┌──────┐ ░  ┌───────┐   ░ ┌──────────┐ ░ ┌─┐
# q1203_0: ──────░─┤0     ├─░──┤ Rz(π) ├───░─┤0         ├─░─┤M├────────────
#          ┌───┐ ░ │      │ ░ ┌┴───────┴┐  ░ │          │ ░ └╥┘┌─┐
# q1203_1: ┤ X ├─░─┤1     ├─░─┤ Rz(π/2) ├──░─┤1         ├─░──╫─┤M├─────────
#          └───┘ ░ │      │ ░ ├─────────┤  ░ │          │ ░  ║ └╥┘┌─┐
# q1203_2: ──────░─┤2 qft ├─░─┤ Rz(π/4) ├──░─┤2 inv_qft ├─░──╫──╫─┤M├──────
#          ┌───┐ ░ │      │ ░ ├─────────┤  ░ │          │ ░  ║  ║ └╥┘┌─┐
# q1203_3: ┤ X ├─░─┤3     ├─░─┤ Rz(π/8) ├──░─┤3         ├─░──╫──╫──╫─┤M├───
#          └───┘ ░ │      │ ░ ├─────────┴┐ ░ │          │ ░  ║  ║  ║ └╥┘┌─┐
# q1203_4: ──────░─┤4     ├─░─┤ Rz(π/16) ├─░─┤4         ├─░──╫──╫──╫──╫─┤M├
#                ░ └──────┘ ░ └──────────┘ ░ └──────────┘ ░  ║  ║  ║  ║ └╥┘
#   c71: 5/══════════════════════════════════════════════════╩══╩══╩══╩══╩═
#                                                            0  1  2  3  4
#
# QFT Circuit =
#                ░                  ░                             ░            »
# q1204_0: ──────░──────────────────░─────────────────────────────░────────────»
#                ░                  ░                             ░            »
# q1204_1: ──────░──────────────────░─────────────────────────────░──────■─────»
#                ░                  ░                       ┌───┐ ░      │     »
# q1204_2: ──────░──────────────────░──────■──────────■─────┤ H ├─░──────┼─────»
#                ░            ┌───┐ ░      │     ┌────┴────┐└───┘ ░      │     »
# q1204_3: ──────░──────■─────┤ H ├─░──────┼─────┤ Rz(π/2) ├──────░──────┼─────»
#          ┌───┐ ░ ┌────┴────┐└───┘ ░ ┌────┴────┐└─────────┘      ░ ┌────┴────┐»
# q1204_4: ┤ H ├─░─┤ Rz(π/2) ├──────░─┤ Rz(π/4) ├─────────────────░─┤ Rz(π/8) ├»
#          └───┘ ░ └─────────┘      ░ └─────────┘                 ░ └─────────┘»
# «                                     ░                                   »
# «q1204_0: ────────────────────────────░──────■───────────■──────────■─────»
# «                               ┌───┐ ░      │           │          │     »
# «q1204_1: ─────■──────────■─────┤ H ├─░──────┼───────────┼──────────┼─────»
# «              │     ┌────┴────┐└───┘ ░      │           │     ┌────┴────┐»
# «q1204_2: ─────┼─────┤ Rz(π/2) ├──────░──────┼───────────┼─────┤ Rz(π/4) ├»
# «         ┌────┴────┐└─────────┘      ░      │      ┌────┴────┐└─────────┘»
# «q1204_3: ┤ Rz(π/4) ├─────────────────░──────┼──────┤ Rz(π/8) ├───────────»
# «         └─────────┘                 ░ ┌────┴─────┐└─────────┘           »
# «q1204_4: ────────────────────────────░─┤ Rz(π/16) ├──────────────────────»
# «                                     ░ └──────────┘                      »
# «                    ┌───┐ ░
# «q1204_0: ─────■─────┤ H ├─░─
# «         ┌────┴────┐└───┘ ░
# «q1204_1: ┤ Rz(π/2) ├──────░─
# «         └─────────┘      ░
# «q1204_2: ─────────────────░─
# «                          ░
# «q1204_3: ─────────────────░─
# «                          ░
# «q1204_4: ─────────────────░─
# «                          ░
#
# Inverse QFT Circuit =
#          ┌───┐                                                  ░      »
# q1205_0: ┤ H ├─────■───────────■───────────■────────────■───────░──────»
#          └───┘┌────┴─────┐     │           │            │       ░ ┌───┐»
# q1205_1: ─────┤ Rz(-π/2) ├─────┼───────────┼────────────┼───────░─┤ H ├»
#               └──────────┘┌────┴─────┐     │            │       ░ └───┘»
# q1205_2: ─────────────────┤ Rz(-π/4) ├─────┼────────────┼───────░──────»
#                           └──────────┘┌────┴─────┐      │       ░      »
# q1205_3: ─────────────────────────────┤ Rz(-π/8) ├──────┼───────░──────»
#                                       └──────────┘┌─────┴─────┐ ░      »
# q1205_4: ─────────────────────────────────────────┤ Rz(-π/16) ├─░──────»
#                                                   └───────────┘ ░      »
# «                                              ░                              »
# «q1205_0: ─────────────────────────────────────░──────────────────────────────»
# «                                              ░                              »
# «q1205_1: ─────■───────────■───────────■───────░──────────────────────────────»
# «         ┌────┴─────┐     │           │       ░ ┌───┐                        »
# «q1205_2: ┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■───────────■──────»
# «         └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐     │      »
# «q1205_3: ────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├─────┼──────»
# «                     └──────────┘┌────┴─────┐ ░      └──────────┘┌────┴─────┐»
# «q1205_4: ────────────────────────┤ Rz(-π/8) ├─░──────────────────┤ Rz(-π/4) ├»
# «                                 └──────────┘ ░                  └──────────┘»
# «          ░                   ░       ░
# «q1205_0: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q1205_1: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q1205_2: ─░───────────────────░───────░─
# «          ░ ┌───┐             ░       ░
# «q1205_3: ─░─┤ H ├─────■───────░───────░─
# «          ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q1205_4: ─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «          ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Quantum Fourier Transform - Method 2

# %%
import sys
sys.path.insert(1, "quantum-fourier-transform/qiskit")
import qft_benchmark
qft_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Quantum Fourier Transform (2) Benchmark Program - Qiskit
# ... execution starting at Nov 02, 2023 17:01:29 UTC
# ************
# Executing [3] circuits with num_qubits = 2
# ... number of gates, depth = 9, 5
# ************
# Executing [3] circuits with num_qubits = 3
# ... number of gates, depth = 15, 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 6, 0.143
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 8, 0.262, 2.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.017, 0.617, 0.036 secs
# Average Transpiling, Validating, Running Times for group 2 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0.994, 0.992
#
# ************
# Executing [3] circuits with num_qubits = 4
# ... number of gates, depth = 22, 12
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 9, 0.25
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 16, 0.327, 6.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.005, 0.965, 0.052 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.976, 0.972
#
# ************
# Executing [3] circuits with num_qubits = 5
# ... number of gates, depth = 30, 17
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 13, 0.333
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 27, 0.36, 12.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.005, 1.027, 0.021 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.945, 0.941
#
# ************
# Executing [3] circuits with num_qubits = 6
# ... number of gates, depth = 39, 23
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 18, 0.4
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 41, 0.382, 20.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.008, 1.126, 0.036 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.923, 0.921
#
# ************
# Executing [3] circuits with num_qubits = 7
# ... number of gates, depth = 49, 30
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 24, 0.455
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 58, 0.395, 30.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.005, 1.307, 0.043 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.874, 0.872
#
# ************
# Executing [3] circuits with num_qubits = 8
# ... number of gates, depth = 60, 38
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 31, 0.5
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 78, 0.412, 42.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.008, 1.537, 0.071 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.846, 0.844
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 39, 0.538
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 101, 0.42, 56.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.005, 1.01, 0.085 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.792, 0.792
#
# ... execution complete at Nov 02, 2023 17:01:37 UTC in 8.491 secs
#
# Sample Circuit:
#          ┌───┐┌─────────┐ ┌──────────┐┌─┐
# q1625_0: ┤ H ├┤ Rz(10π) ├─┤0         ├┤M├────────────
#          ├───┤└┬────────┤ │          │└╥┘┌─┐
# q1625_1: ┤ H ├─┤ Rz(5π) ├─┤1         ├─╫─┤M├─────────
#          ├───┤┌┴────────┴┐│          │ ║ └╥┘┌─┐
# q1625_2: ┤ H ├┤ Rz(5π/2) ├┤2 inv_qft ├─╫──╫─┤M├──────
#          ├───┤├──────────┤│          │ ║  ║ └╥┘┌─┐
# q1625_3: ┤ H ├┤ Rz(5π/4) ├┤3         ├─╫──╫──╫─┤M├───
#          ├───┤├──────────┤│          │ ║  ║  ║ └╥┘┌─┐
# q1625_4: ┤ H ├┤ Rz(5π/8) ├┤4         ├─╫──╫──╫──╫─┤M├
#          └───┘└──────────┘└──────────┘ ║  ║  ║  ║ └╥┘
#   c92: 5/══════════════════════════════╩══╩══╩══╩══╩═
#                                        0  1  2  3  4
#
# Inverse QFT Circuit =
#          ┌───┐                                                  ░      »
# q1626_0: ┤ H ├─────■───────────■───────────■────────────■───────░──────»
#          └───┘┌────┴─────┐     │           │            │       ░ ┌───┐»
# q1626_1: ─────┤ Rz(-π/2) ├─────┼───────────┼────────────┼───────░─┤ H ├»
#               └──────────┘┌────┴─────┐     │            │       ░ └───┘»
# q1626_2: ─────────────────┤ Rz(-π/4) ├─────┼────────────┼───────░──────»
#                           └──────────┘┌────┴─────┐      │       ░      »
# q1626_3: ─────────────────────────────┤ Rz(-π/8) ├──────┼───────░──────»
#                                       └──────────┘┌─────┴─────┐ ░      »
# q1626_4: ─────────────────────────────────────────┤ Rz(-π/16) ├─░──────»
#                                                   └───────────┘ ░      »
# «                                              ░                              »
# «q1626_0: ─────────────────────────────────────░──────────────────────────────»
# «                                              ░                              »
# «q1626_1: ─────■───────────■───────────■───────░──────────────────────────────»
# «         ┌────┴─────┐     │           │       ░ ┌───┐                        »
# «q1626_2: ┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■───────────■──────»
# «         └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐     │      »
# «q1626_3: ────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├─────┼──────»
# «                     └──────────┘┌────┴─────┐ ░      └──────────┘┌────┴─────┐»
# «q1626_4: ────────────────────────┤ Rz(-π/8) ├─░──────────────────┤ Rz(-π/4) ├»
# «                                 └──────────┘ ░                  └──────────┘»
# «          ░                   ░       ░
# «q1626_0: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q1626_1: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q1626_2: ─░───────────────────░───────░─
# «          ░ ┌───┐             ░       ░
# «q1626_3: ─░─┤ H ├─────■───────░───────░─
# «          ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q1626_4: ─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «          ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Grover

# %%
import sys
sys.path.insert(1, "grovers/qiskit")
import grovers_benchmark
grovers_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Grover's Search Benchmark Program - Qiskit
# ... execution starting at Nov 02, 2023 17:01:44 UTC
# ************
# Executing [3] circuits with num_qubits = 2
# ************
# Executing [3] circuits with num_qubits = 3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 13, 0.116
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 13, 0.123, 2.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.002, 0.697, 0.103 secs
# Average Transpiling, Validating, Running Times for group 2 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0.003, 0.0
#
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 25, 0.083
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 51, 0.303, 24.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.013, 1.295, 0.026 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.974, 0.961
#
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 38, 0.072
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 167, 0.394, 84.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.024, 2.663, 0.109 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.823, 0.781
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 47, 0.064
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 604, 0.379, 288.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.021, 5.836, 0.136 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.306, 0.275
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 70, 0.056
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 1877, 0.474, 1104.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.046, 11.624, 0.498 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.047, 0.014
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 87, 0.048
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 5062, 0.484, 3008.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.103, 28.963, 2.223 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.02, 0.0
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 122, 0.045
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 15271, 0.492, 9120.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.214, 33.117, 6.513 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.004, 0.0
#
# ... execution complete at Nov 02, 2023 17:03:29 UTC in 105.476 secs
#
# Sample Circuit:
#          ┌───┐ ░ ┌─────────┐┌───────────┐ ░ ┌─────────┐┌───────────┐ ░ »
# q2081_0: ┤ H ├─░─┤0        ├┤0          ├─░─┤0        ├┤0          ├─░─»
#          ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q2081_1: ┤ H ├─░─┤1        ├┤1          ├─░─┤1        ├┤1          ├─░─»
#          ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q2081_2: ┤ H ├─░─┤2 oracle ├┤2 diffuser ├─░─┤2 oracle ├┤2 diffuser ├─░─»
#          ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q2081_3: ┤ H ├─░─┤3        ├┤3          ├─░─┤3        ├┤3          ├─░─»
#          ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q2081_4: ┤ H ├─░─┤4        ├┤4          ├─░─┤4        ├┤4          ├─░─»
#          └───┘ ░ └─────────┘└───────────┘ ░ └─────────┘└───────────┘ ░ »
#  c113: 5/══════════════════════════════════════════════════════════════»
#                                                                        »
# «         ┌─────────┐┌───────────┐ ░ ┌─────────┐┌───────────┐ ░ ┌─┐
# «q2081_0: ┤0        ├┤0          ├─░─┤0        ├┤0          ├─░─┤M├────────────
# «         │         ││           │ ░ │         ││           │ ░ └╥┘┌─┐
# «q2081_1: ┤1        ├┤1          ├─░─┤1        ├┤1          ├─░──╫─┤M├─────────
# «         │         ││           │ ░ │         ││           │ ░  ║ └╥┘┌─┐
# «q2081_2: ┤2 oracle ├┤2 diffuser ├─░─┤2 oracle ├┤2 diffuser ├─░──╫──╫─┤M├──────
# «         │         ││           │ ░ │         ││           │ ░  ║  ║ └╥┘┌─┐
# «q2081_3: ┤3        ├┤3          ├─░─┤3        ├┤3          ├─░──╫──╫──╫─┤M├───
# «         │         ││           │ ░ │         ││           │ ░  ║  ║  ║ └╥┘┌─┐
# «q2081_4: ┤4        ├┤4          ├─░─┤4        ├┤4          ├─░──╫──╫──╫──╫─┤M├
# «         └─────────┘└───────────┘ ░ └─────────┘└───────────┘ ░  ║  ║  ║  ║ └╥┘
# « c113: 5/═══════════════════════════════════════════════════════╩══╩══╩══╩══╩═
# «                                                                0  1  2  3  4
#
# Oracle =
#          ┌───┐                ░ ┌───┐
# q2088_0: ┤ X ├───────■────────░─┤ X ├
#          ├───┤       │        ░ ├───┤
# q2088_1: ┤ X ├───────■────────░─┤ X ├
#          └───┘       │        ░ └───┘
# q2088_2: ────────────■────────░──────
#                      │        ░
# q2088_3: ────────────■────────░──────
#          ┌───┐┌───┐┌─┴─┐┌───┐ ░ ┌───┐
# q2088_4: ┤ X ├┤ H ├┤ X ├┤ H ├─░─┤ X ├
#          └───┘└───┘└───┘└───┘ ░ └───┘
#
# Diffuser =
#          ┌───┐┌───┐                ░ ┌───┐┌───┐
# q2089_0: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#          ├───┤├───┤       │        ░ ├───┤├───┤
# q2089_1: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#          ├───┤├───┤       │        ░ ├───┤├───┤
# q2089_2: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#          ├───┤├───┤       │        ░ ├───┤├───┤
# q2089_3: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#          ├───┤├───┤┌───┐┌─┴─┐┌───┐ ░ ├───┤├───┤
# q2089_4: ┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├─░─┤ X ├┤ H ├
#          └───┘└───┘└───┘└───┘└───┘ ░ └───┘└───┘

# %% [markdown]
# ### Phase Estimation

# %%
import sys
sys.path.insert(1, "phase-estimation/qiskit")
import pe_benchmark
pe_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Phase Estimation Benchmark Program - Qiskit
# ... execution starting at Nov 02, 2023 17:03:39 UTC
# ************
# Executing [2] circuits with num_qubits = 3
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 16, 0.316
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 14, 0.207, 4.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.028, 0.573, 0.023 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.984, 0.979
#
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 27, 0.353
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 30, 0.295, 11.333
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.033, 1.218, 0.035 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.956, 0.95
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 41, 0.377
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 43, 0.324, 18.667
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.036, 1.546, 0.022 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.934, 0.93
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 58, 0.395
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 59, 0.344, 27.333
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.02, 1.684, 0.039 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.901, 0.897
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 78, 0.408
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 82, 0.364, 40.667
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.036, 1.737, 0.07 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.85, 0.848
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 101, 0.418
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 109, 0.378, 56.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.029, 1.036, 0.092 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.795, 0.794
#
# ... execution complete at Nov 02, 2023 17:03:48 UTC in 8.833 secs
#
# Sample Circuit:
#          ┌───┐ ░                              ░ ┌──────────┐ ░ ┌─┐
# q2643_0: ┤ H ├─░─────────────────────────■────░─┤0         ├─░─┤M├─────────
#          ├───┤ ░                         │    ░ │          │ ░ └╥┘┌─┐
# q2643_1: ┤ H ├─░──────────────────■──────┼────░─┤1         ├─░──╫─┤M├──────
#          ├───┤ ░                  │      │    ░ │  inv_qft │ ░  ║ └╥┘┌─┐
# q2643_2: ┤ H ├─░───────────■──────┼──────┼────░─┤2         ├─░──╫──╫─┤M├───
#          ├───┤ ░           │      │      │    ░ │          │ ░  ║  ║ └╥┘┌─┐
# q2643_3: ┤ H ├─░────■──────┼──────┼──────┼────░─┤3         ├─░──╫──╫──╫─┤M├
#          ├───┤ ░ ┌──┴──┐┌──┴──┐┌──┴──┐┌──┴──┐ ░ └──────────┘ ░  ║  ║  ║ └╥┘
# q2643_4: ┤ X ├─░─┤ U^1 ├┤ U^2 ├┤ U^4 ├┤ U^8 ├─░──────────────░──╫──╫──╫──╫─
#          └───┘ ░ └─────┘└─────┘└─────┘└─────┘ ░              ░  ║  ║  ║  ║
#  c130: 4/═══════════════════════════════════════════════════════╩══╩══╩══╩═
#                                                                 0  1  2  3
#
# Phase Operator 'U' =
#    ┌────────┐
# q: ┤ P(π/4) ├
#    └────────┘
#
# Inverse QFT Circuit =
#          ┌───┐                                     ░                  »
# q2645_0: ┤ H ├─────■───────────■───────────■───────░──────────────────»
#          └───┘┌────┴─────┐     │           │       ░ ┌───┐            »
# q2645_1: ─────┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■──────»
#               └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐»
# q2645_2: ─────────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├»
#                           └──────────┘┌────┴─────┐ ░      └──────────┘»
# q2645_3: ─────────────────────────────┤ Rz(-π/8) ├─░──────────────────»
#                                       └──────────┘ ░                  »
# «                      ░                   ░       ░
# «q2645_0: ─────────────░───────────────────░───────░─
# «                      ░                   ░       ░
# «q2645_1: ─────■───────░───────────────────░───────░─
# «              │       ░ ┌───┐             ░       ░
# «q2645_2: ─────┼───────░─┤ H ├─────■───────░───────░─
# «         ┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q2645_3: ┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «         └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### HHL Linear Solver

# %%
import sys
sys.path.insert(1, "hhl/qiskit")
import hhl_benchmark

hhl_benchmark.verbose=False

hhl_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=1, use_best_widths=True,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# HHL Benchmark Program - Qiskit
# ... execution starting at Nov 02, 2023 17:03:54 UTC
# ************
# Executing 3 circuits with 4 qubits, using 1 input qubits and 1 clock qubits
# ************
# Executing 3 circuits with 5 qubits, using 1 input qubits and 2 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 11, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 114, 0.307, 50.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.285, 4.271, 0.918 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.998, 0.98
#
# ************
# Executing 3 circuits with 6 qubits, using 1 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 13, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 212, 0.317, 100.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.653, 6.397, 1.542 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.985, 0.845
#
# ************
# Executing 3 circuits with 7 qubits, using 2 input qubits and 2 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 15, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 315, 0.323, 152.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.481, 7.295, 1.652 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.966, 0.663
#
# ************
# Executing 3 circuits with 8 qubits, using 2 input qubits and 3 clock qubits
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 13, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 272, 0.329, 176.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.492, 8.64, 2.055 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.778, 0.596
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 15, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 411, 0.331, 264.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.541, 7.438, 3.28 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.695, 0.446
#
# ... execution complete at Nov 02, 2023 17:04:32 UTC in 38.075 secs
#
# Sample Circuit:
#          ┌───┐ ░ ┌───────────┐ ░          ░                           ░        »
#   input: ┤ X ├─░─┤0          ├─░──────────░───────────────────────────░────────»
#          └───┘ ░ │           │ ░          ░                           ░        »
#  in_anc: ──────░─┤1          ├─░──────────░───────────────────────────░────────»
#          ┌───┐ ░ │  e^{0iAt} │ ░ ┌──────┐ ░      ┌──────────┐         ░ ┌─────┐»
#   clock: ┤ H ├─░─┤2          ├─░─┤ IQFT ├─░──────┤0         ├─────────░─┤ QFT ├»
#          └───┘ ░ │           │ ░ └──────┘ ░      │  INV_ROT │┌─┐      ░ └─────┘»
# ancilla: ──────░─┤3          ├─░──────────░──|0>─┤1         ├┤M├─|0>──░────────»
#                ░ └───────────┘ ░          ░      └──────────┘└╥┘      ░        »
#  c140: 1/═════════════════════════════════════════════════════╬════════════════»
#                                                               ║                »
#  c141: 1/═════════════════════════════════════════════════════╩════════════════»
#                                                               0                »
# «          ░ ┌────────────┐ ░       ░ ┌─┐
# «  input: ─░─┤0           ├─░───────░─┤M├
# «          ░ │            │ ░       ░ └╥┘
# « in_anc: ─░─┤1           ├─░───────░──╫─
# «          ░ │  e^{-0iAt} │ ░ ┌───┐ ░  ║
# «  clock: ─░─┤2           ├─░─┤ H ├─░──╫─
# «          ░ │            │ ░ └───┘ ░  ║
# «ancilla: ─░─┤3           ├─░───────░──╫─
# «          ░ └────────────┘ ░       ░  ║
# « c140: 1/═════════════════════════════╩═
# «                                      0
# « c141: 1/═══════════════════════════════
# «
#
# U Circuit =
#        ┌───┐            ┌───┐   ┌───────────┐┌──────────┐┌───────────┐     »
# q2940: ┤ X ├────■───────┤ X ├───┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├──■──»
#        └───┘  ┌─┴─┐   ┌─┴───┴──┐└┬──────────┤└┬────────┬┘└───────────┘┌─┴─┐»
# q2941: ───────┤ X ├───┤ Rz(-π) ├─┤ Ry(-π/2) ├─┤ Rz(-π) ├──────────────┤ X ├»
#               └───┘   └────────┘ └──────────┘ └────────┘              └───┘»
# q2942: ──────■─────────────────────────────────────────────────────────────»
#        ┌───┐ │P(3π/2)   ┌───┐                                              »
# q2943: ┤ X ├─■──────────┤ X ├──────────────────────────────────────────────»
#        └───┘            └───┘                                              »
# «        ┌──────────┐┌───────────┐                             ┌───┐»
# «q2940: ─┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────┤ X ├»
# «       ┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐└─┬─┘»
# «q2941: ┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├──■──»
# «       └───────────┘  └────────┘ └───┘└──────────┘└──────────┘     »
# «q2942: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «q2943: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «       ┌───────────┐                  ┌───────────┐┌──────────┐┌───────────┐»
# «q2940: ┤ Rz(-3π/2) ├──■────────────■──┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├»
# «       └───┬───┬───┘  │            │  └───┬───┬───┘└┬────────┬┘└┬──────────┤»
# «q2941: ────┤ X ├──────■────────────■──────┤ X ├─────┤ Rz(-π) ├──┤ Ry(-π/2) ├»
# «           └───┘      │            │      └───┘     └────────┘  └──────────┘»
# «q2942: ───────────────┼───■────────┼────────────────────────────────────────»
# «                    ┌─┴─┐ │P(-π) ┌─┴─┐                                      »
# «q2943: ─────────────┤ X ├─■──────┤ X ├──────────────────────────────────────»
# «                    └───┘        └───┘                                      »
# «                       ┌──────────┐┌───────────┐                             »
# «q2940: ────────────■───┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────»
# «       ┌────────┐┌─┴─┐┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐»
# «q2941: ┤ Rz(-π) ├┤ X ├┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├»
# «       └────────┘└───┘└───────────┘  └────────┘ └───┘└──────────┘└──────────┘»
# «q2942: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q2943: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «       ┌───┐┌───────────┐┌───┐     ┌───┐
# «q2940: ┤ X ├┤ Rz(-3π/2) ├┤ X ├──■──┤ X ├
# «       └─┬─┘└───────────┘└───┘┌─┴─┐└───┘
# «q2941: ──■────────────────────┤ X ├─────
# «                              └───┘
# «q2942: ─────────────────────────────────
# «
# «q2943: ─────────────────────────────────
# «
#
# U^-1 Circuit =
#        ┌───┐             ┌───┐   ┌───────────┐┌──────────┐┌───────────┐     »
# q2948: ┤ X ├─────■───────┤ X ├───┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├──■──»
#        └───┘   ┌─┴─┐   ┌─┴───┴──┐└┬──────────┤└┬────────┬┘└───────────┘┌─┴─┐»
# q2949: ────────┤ X ├───┤ Rz(-π) ├─┤ Ry(-π/2) ├─┤ Rz(-π) ├──────────────┤ X ├»
#                └───┘   └────────┘ └──────────┘ └────────┘              └───┘»
# q2950: ──────■──────────────────────────────────────────────────────────────»
#        ┌───┐ │P(-3π/2)   ┌───┐                                              »
# q2951: ┤ X ├─■───────────┤ X ├──────────────────────────────────────────────»
#        └───┘             └───┘                                              »
# «        ┌──────────┐┌───────────┐                             ┌───┐»
# «q2948: ─┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────┤ X ├»
# «       ┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐└─┬─┘»
# «q2949: ┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├──■──»
# «       └───────────┘  └────────┘ └───┘└──────────┘└──────────┘     »
# «q2950: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «q2951: ────────────────────────────────────────────────────────────»
# «                                                                   »
# «       ┌───────────┐                 ┌───────────┐┌──────────┐┌───────────┐»
# «q2948: ┤ Rz(-3π/2) ├──■───────────■──┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├»
# «       └───┬───┬───┘  │           │  └───┬───┬───┘└┬────────┬┘└┬──────────┤»
# «q2949: ────┤ X ├──────■───────────■──────┤ X ├─────┤ Rz(-π) ├──┤ Ry(-π/2) ├»
# «           └───┘      │           │      └───┘     └────────┘  └──────────┘»
# «q2950: ───────────────┼───■───────┼────────────────────────────────────────»
# «                    ┌─┴─┐ │P(π) ┌─┴─┐                                      »
# «q2951: ─────────────┤ X ├─■─────┤ X ├──────────────────────────────────────»
# «                    └───┘       └───┘                                      »
# «                       ┌──────────┐┌───────────┐                             »
# «q2948: ────────────■───┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────»
# «       ┌────────┐┌─┴─┐┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐»
# «q2949: ┤ Rz(-π) ├┤ X ├┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├»
# «       └────────┘└───┘└───────────┘  └────────┘ └───┘└──────────┘└──────────┘»
# «q2950: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q2951: ──────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «       ┌───┐┌───────────┐┌───┐     ┌───┐
# «q2948: ┤ X ├┤ Rz(-3π/2) ├┤ X ├──■──┤ X ├
# «       └─┬─┘└───────────┘└───┘┌─┴─┐└───┘
# «q2949: ──■────────────────────┤ X ├─────
# «                              └───┘
# «q2950: ─────────────────────────────────
# «
# «q2951: ─────────────────────────────────
# «
#
# QFT Circuit =
#        ┌───┐ ░
# q2947: ┤ H ├─░─
#        └───┘ ░
#
# Inverse QFT Circuit =
#        ┌───┐ ░
# q2944: ┤ H ├─░─
#        └───┘ ░
#
# Hamiltonian Phase Estimation Circuit =
#   ... too large!
#
# Controlled Rotation Circuit =
#
# q2945: ─────────────────■────────────────────■──
#        ┌─────────────┐┌─┴─┐┌──────────────┐┌─┴─┐
# q2946: ┤ Ry(0.77628) ├┤ X ├┤ Ry(-0.27092) ├┤ X ├
#        └─────────────┘└───┘└──────────────┘└───┘

# %% [markdown]
# ### Amplitude Estimation

# %%
import sys
sys.path.insert(1, "amplitude-estimation/qiskit")
import ae_benchmark
ae_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Amplitude Estimation Benchmark Program - Qiskit
# ... execution starting at Nov 02, 2023 17:04:38 UTC
# ************
# Executing [2] circuits with num_qubits = 3
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 72, 0.422
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 58, 0.387, 29.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.055, 1.104, 0.023 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.926, 0.852
#
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 208, 0.432
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 165, 0.398, 84.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.078, 3.146, 0.037 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.811, 0.669
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 479, 0.436
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 375, 0.404, 192.667
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.089, 5.542, 0.064 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.63, 0.507
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 1017, 0.438
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 836, 0.407, 426.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.107, 12.827, 0.194 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.388, 0.316
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 2086, 0.439
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 1701, 0.408, 868.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.27, 32.856, 0.795 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.191, 0.137
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 4214, 0.44
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 3417, 0.409, 1744.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.791, 19.104, 1.189 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.089, 0.059
#
# ... execution complete at Nov 02, 2023 17:06:01 UTC in 83.491 secs
#
# Sample Circuit:
#          ┌───┐                         ┌──────┐┌──────┐┌──────┐┌──────┐ ░ »
# q3961_0: ┤ H ├─────────────────────────┤0     ├┤0     ├┤0     ├┤0     ├─░─»
#          ├───┤         ┌──────┐┌──────┐│      ││      ││      ││      │ ░ »
# q3961_1: ┤ H ├─────────┤0     ├┤0     ├┤      ├┤      ├┤      ├┤      ├─░─»
#          ├───┤ ┌──────┐│      ││      ││      ││      ││      ││      │ ░ »
# q3961_2: ┤ H ├─┤0     ├┤      ├┤      ├┤  c_Q ├┤  c_Q ├┤  c_Q ├┤  c_Q ├─░─»
#          ├───┴┐│      ││  c_Q ││  c_Q ││      ││      ││      ││      │ ░ »
# q3960_0: ┤0   ├┤1 c_Q ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├─░─»
#          │  A ││      ││      ││      ││      ││      ││      ││      │ ░ »
# q3960_1: ┤1   ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├─░─»
#          └────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘ ░ »
#  c177: 3/═════════════════════════════════════════════════════════════════»
#                                                                           »
# «         ┌──────────┐ ░ ┌─┐
# «q3961_0: ┤0         ├─░─┤M├──────
# «         │          │ ░ └╥┘┌─┐
# «q3961_1: ┤1 inv_qft ├─░──╫─┤M├───
# «         │          │ ░  ║ └╥┘┌─┐
# «q3961_2: ┤2         ├─░──╫──╫─┤M├
# «         └──────────┘ ░  ║  ║ └╥┘
# «q3960_0: ─────────────░──╫──╫──╫─
# «                      ░  ║  ║  ║
# «q3960_1: ─────────────░──╫──╫──╫─
# «                      ░  ║  ║  ║
# « c177: 3/════════════════╩══╩══╩═
# «                         0  1  2
#
# Controlled Quantum Operator 'cQ' =
#
# q4278: ──■───
#        ┌─┴──┐
#   q_0: ┤0   ├
#        │  Q │
#   q_1: ┤1   ├
#        └────┘
#
# Quantum Operator 'Q' =
#                     ┌───────┐┌───┐          ┌───┐     ┌────┐
# q_0: ───────────────┤0      ├┤ X ├───────■──┤ X ├─────┤0   ├
#      ┌───┐┌───┐┌───┐│  A_dg │├───┤┌───┐┌─┴─┐├───┤┌───┐│  A │
# q_1: ┤ X ├┤ Z ├┤ X ├┤1      ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤1   ├
#      └───┘└───┘└───┘└───────┘└───┘└───┘└───┘└───┘└───┘└────┘
#
# Amplitude Generator 'A' =
#                              ┌───┐
# q_0: ────────────────────────┤ X ├
#      ┌────────────┐┌───┐┌───┐└─┬─┘
# q_1: ┤ Ry(2.0624) ├┤ X ├┤ X ├──■──
#      └────────────┘└───┘└───┘
#
# Inverse QFT Circuit =
#          ┌───┐                         ░                   ░       ░
# q3963_0: ┤ H ├─────■───────────■───────░───────────────────░───────░─
#          └───┘┌────┴─────┐     │       ░ ┌───┐             ░       ░
# q3963_1: ─────┤ Rz(-π/2) ├─────┼───────░─┤ H ├─────■───────░───────░─
#               └──────────┘┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# q3963_2: ─────────────────┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
#                           └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Monte Carlo

# %%
import sys
sys.path.insert(1, "monte-carlo/qiskit")
import mc_benchmark
mc_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Monte Carlo Sampling (2) Benchmark Program - Qiskit
# ... execution starting at Nov 02, 2023 17:06:12 UTC
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 202, 0.398
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 208, 0.372, 96.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.119, 3.999, 0.09 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.794, 0.588
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 468, 0.401
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 479, 0.377, 224.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.122, 9.153, 0.111 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.596, 0.462
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 997, 0.402
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 1017, 0.38, 478.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.131, 18.724, 0.263 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.37, 0.281
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 2049, 0.402
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 2086, 0.382, 982.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.429, 32.108, 1.021 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.213, 0.16
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 4144, 0.403
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 4214, 0.382, 1984.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.694, 18.786, 1.565 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.096, 0.067
#
# ... execution complete at Nov 02, 2023 17:07:47 UTC in 95.524 secs
#
# Sample Circuit:
#          ┌────┐┌──────┐┌──────┐┌──────┐┌──────┐┌──────┐┌──────┐┌──────┐ ░ »
# q4508_0: ┤0   ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├─░─»
#          │  A ││      ││      ││      ││      ││      ││      ││      │ ░ »
# q4508_1: ┤1   ├┤2     ├┤2     ├┤2     ├┤2 c_Q ├┤2 c_Q ├┤2 c_Q ├┤2 c_Q ├─░─»
#          ├───┬┘│      ││  c_Q ││  c_Q ││      ││      ││      ││      │ ░ »
# q4509_0: ┤ H ├─┤  c_Q ├┤      ├┤      ├┤0     ├┤0     ├┤0     ├┤0     ├─░─»
#          ├───┤ │      ││      ││      │└──────┘└──────┘└──────┘└──────┘ ░ »
# q4509_1: ┤ H ├─┤      ├┤0     ├┤0     ├─────────────────────────────────░─»
#          ├───┤ │      │└──────┘└──────┘                                 ░ »
# q4509_2: ┤ H ├─┤0     ├─────────────────────────────────────────────────░─»
#          └───┘ └──────┘                                                 ░ »
#  c192: 3/═════════════════════════════════════════════════════════════════»
#                                                                           »
# «                      ░
# «q4508_0: ─────────────░──────────
# «                      ░
# «q4508_1: ─────────────░──────────
# «         ┌──────────┐ ░ ┌─┐
# «q4509_0: ┤0         ├─░─┤M├──────
# «         │          │ ░ └╥┘┌─┐
# «q4509_1: ┤1 inv_qft ├─░──╫─┤M├───
# «         │          │ ░  ║ └╥┘┌─┐
# «q4509_2: ┤2         ├─░──╫──╫─┤M├
# «         └──────────┘ ░  ║  ║ └╥┘
# « c192: 3/════════════════╩══╩══╩═
# «                         0  1  2
#
# Controlled Quantum Operator 'cQ' =
#
# q4758: ──■───
#        ┌─┴──┐
#   q_0: ┤0   ├
#        │  Q │
#   q_1: ┤1   ├
#        └────┘
#
# Quantum Operator 'Q' =
#                     ┌───────┐┌───┐          ┌───┐     ┌────┐
# q_0: ───────────────┤0      ├┤ X ├───────■──┤ X ├─────┤0   ├
#      ┌───┐┌───┐┌───┐│  A_dg │├───┤┌───┐┌─┴─┐├───┤┌───┐│  A │
# q_1: ┤ X ├┤ Z ├┤ X ├┤1      ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤1   ├
#      └───┘└───┘└───┘└───────┘└───┘└───┘└───┘└───┘└───┘└────┘
#
# Amplitude Generator 'A' =
#          ┌────┐┌────┐
# q4753_0: ┤0   ├┤0   ├
#          │  R ││  F │
# q4753_1: ┤1   ├┤1   ├
#          └────┘└────┘
#
# Distribution Generator 'R' =
#          ┌───┐
# q4754_0: ┤ H ├
#          └───┘
# q4754_1: ─────
#
#
# Function Generator 'F' =
#
# q4755_0: ──■──
#          ┌─┴─┐
# q4755_1: ┤ X ├
#          └───┘
#
# Inverse QFT Circuit =
#          ┌───┐                         ░                   ░       ░
# q4511_0: ┤ H ├─────■───────────■───────░───────────────────░───────░─
#          └───┘┌────┴─────┐     │       ░ ┌───┐             ░       ░
# q4511_1: ─────┤ Rz(-π/2) ├─────┼───────░─┤ H ├─────■───────░───────░─
#               └──────────┘┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# q4511_2: ─────────────────┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
#                           └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Hamiltonian Simulation

# %%
import sys
sys.path.insert(1, "hamiltonian-simulation/qiskit")
import hamiltonian_simulation_benchmark
hamiltonian_simulation_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Hamiltonian Simulation Benchmark Program - Qiskit
# ... execution starting at Nov 02, 2023 17:07:54 UTC
# ************
# Executing [3] circuits with num_qubits = 2
# ************
# Executing [3] circuits with num_qubits = 3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 29, 0.243
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 29, 0.243, 9.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.011, 0.724, 0.021 secs
# Average Transpiling, Validating, Running Times for group 2 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0.972, 0.961
#
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 44, 0.265
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 44, 0.265, 18.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.007, 1.203, 0.03 secs
# Average Transpiling, Validating, Running Times for group 3 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.94, 0.931
#
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 50, 0.276
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 44, 0.293, 27.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.024, 1.47, 0.031 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.917, 0.909
#
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 50, 0.279
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 44, 0.293, 36.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.019, 1.937, 0.032 secs
# Average Transpiling, Validating, Running Times for group 5 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.897, 0.891
#
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 50, 0.283
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 44, 0.306, 45.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.021, 1.894, 0.053 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.877, 0.874
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 50, 0.284
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 44, 0.303, 54.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.031, 1.916, 0.105 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.863, 0.861
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 50, 0.286
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 44, 0.312, 63.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.047, 1.261, 0.111 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.84, 0.839
#
# ... execution complete at Nov 02, 2023 17:08:05 UTC in 11.518 secs
#
# Sample Circuit:
#          ┌───┐ ░ ┌───────────────┐ ┌──────────────┐ ░ ┌─────────────┐»
# q5215_0: ┤ X ├─░─┤ Rx(-0.025609) ├─┤ Rz(0.009192) ├─░─┤0            ├»
#          └───┘ ░ ├───────────────┤┌┴──────────────┤ ░ │  xxyyzz_opt │»
# q5215_1: ──────░─┤ Rx(0.0025855) ├┤ Rz(-0.057871) ├─░─┤1            ├»
#          ┌───┐ ░ └┬──────────────┤└┬──────────────┤ ░ ├─────────────┤»
# q5215_2: ┤ X ├─░──┤ Rx(0.035773) ├─┤ Rz(0.051748) ├─░─┤0            ├»
#          └───┘ ░  ├──────────────┤ ├──────────────┤ ░ │  xxyyzz_opt │»
# q5215_3: ──────░──┤ Rx(0.038563) ├─┤ Rz(0.057288) ├─░─┤1            ├»
#          ┌───┐ ░  ├──────────────┤ ├──────────────┤ ░ ├─────────────┤»
# q5215_4: ┤ X ├─░──┤ Rx(0.049408) ├─┤ Rz(0.023959) ├─░─┤0            ├»
#          └───┘ ░  ├──────────────┤┌┴──────────────┤ ░ │  xxyyzz_opt │»
# q5215_5: ──────░──┤ Rx(-0.04161) ├┤ Rz(0.0059034) ├─░─┤1            ├»
#                ░  └──────────────┘└───────────────┘ ░ └─────────────┘»
#  c216: 6/════════════════════════════════════════════════════════════»
#                                                                      »
# «                         ░ ┌───────────────┐ ┌──────────────┐ ░ »
# «q5215_0: ────────────────░─┤ Rx(-0.025609) ├─┤ Rz(0.009192) ├─░─»
# «         ┌─────────────┐ ░ ├───────────────┤┌┴──────────────┤ ░ »
# «q5215_1: ┤0            ├─░─┤ Rx(0.0025855) ├┤ Rz(-0.057871) ├─░─»
# «         │  xxyyzz_opt │ ░ └┬──────────────┤└┬──────────────┤ ░ »
# «q5215_2: ┤1            ├─░──┤ Rx(0.035773) ├─┤ Rz(0.051748) ├─░─»
# «         ├─────────────┤ ░  ├──────────────┤ ├──────────────┤ ░ »
# «q5215_3: ┤0            ├─░──┤ Rx(0.038563) ├─┤ Rz(0.057288) ├─░─»
# «         │  xxyyzz_opt │ ░  ├──────────────┤ ├──────────────┤ ░ »
# «q5215_4: ┤1            ├─░──┤ Rx(0.049408) ├─┤ Rz(0.023959) ├─░─»
# «         └─────────────┘ ░  ├──────────────┤┌┴──────────────┤ ░ »
# «q5215_5: ────────────────░──┤ Rx(-0.04161) ├┤ Rz(0.0059034) ├─░─»
# «                         ░  └──────────────┘└───────────────┘ ░ »
# « c216: 6/═══════════════════════════════════════════════════════»
# «                                                                »
# «         ┌─────────────┐                ░ ┌───────────────┐ ┌──────────────┐»
# «q5215_0: ┤0            ├────────────────░─┤ Rx(-0.025609) ├─┤ Rz(0.009192) ├»
# «         │  xxyyzz_opt │┌─────────────┐ ░ ├───────────────┤┌┴──────────────┤»
# «q5215_1: ┤1            ├┤0            ├─░─┤ Rx(0.0025855) ├┤ Rz(-0.057871) ├»
# «         ├─────────────┤│  xxyyzz_opt │ ░ └┬──────────────┤└┬──────────────┤»
# «q5215_2: ┤0            ├┤1            ├─░──┤ Rx(0.035773) ├─┤ Rz(0.051748) ├»
# «         │  xxyyzz_opt │├─────────────┤ ░  ├──────────────┤ ├──────────────┤»
# «q5215_3: ┤1            ├┤0            ├─░──┤ Rx(0.038563) ├─┤ Rz(0.057288) ├»
# «         ├─────────────┤│  xxyyzz_opt │ ░  ├──────────────┤ ├──────────────┤»
# «q5215_4: ┤0            ├┤1            ├─░──┤ Rx(0.049408) ├─┤ Rz(0.023959) ├»
# «         │  xxyyzz_opt │└─────────────┘ ░  ├──────────────┤┌┴──────────────┤»
# «q5215_5: ┤1            ├────────────────░──┤ Rx(-0.04161) ├┤ Rz(0.0059034) ├»
# «         └─────────────┘                ░  └──────────────┘└───────────────┘»
# « c216: 6/═══════════════════════════════════════════════════════════════════»
# «                                                                            »
# «          ░ ┌─────────────┐                ░ ┌─┐
# «q5215_0: ─░─┤0            ├────────────────░─┤M├───────────────
# «          ░ │  xxyyzz_opt │┌─────────────┐ ░ └╥┘┌─┐
# «q5215_1: ─░─┤1            ├┤0            ├─░──╫─┤M├────────────
# «          ░ ├─────────────┤│  xxyyzz_opt │ ░  ║ └╥┘┌─┐
# «q5215_2: ─░─┤0            ├┤1            ├─░──╫──╫─┤M├─────────
# «          ░ │  xxyyzz_opt │├─────────────┤ ░  ║  ║ └╥┘┌─┐
# «q5215_3: ─░─┤1            ├┤0            ├─░──╫──╫──╫─┤M├──────
# «          ░ ├─────────────┤│  xxyyzz_opt │ ░  ║  ║  ║ └╥┘┌─┐
# «q5215_4: ─░─┤0            ├┤1            ├─░──╫──╫──╫──╫─┤M├───
# «          ░ │  xxyyzz_opt │└─────────────┘ ░  ║  ║  ║  ║ └╥┘┌─┐
# «q5215_5: ─░─┤1            ├────────────────░──╫──╫──╫──╫──╫─┤M├
# «          ░ └─────────────┘                ░  ║  ║  ║  ║  ║ └╥┘
# « c216: 6/═════════════════════════════════════╩══╩══╩══╩══╩══╩═
# «                                              0  1  2  3  4  5
#
# XXYYZZ_opt =
#                        ┌───┐┌─────────────┐                    ┌───┐»
# q5479_0: ──────────────┤ X ├┤ Rz(-1.5603) ├──■─────────────────┤ X ├»
#          ┌────────────┐└─┬─┘└┬────────────┤┌─┴─┐┌─────────────┐└─┬─┘»
# q5479_1: ┤ Rz(1.5708) ├──■───┤ Ry(1.5603) ├┤ X ├┤ Ry(-1.5603) ├──■──»
#          └────────────┘      └────────────┘└───┘└─────────────┘     »
# «         ┌─────────────┐
# «q5479_0: ┤ Rz(-1.5708) ├
# «         └─────────────┘
# «q5479_1: ───────────────
# «

# %% [markdown]
# ### VQE - Method 1

# %%
import sys
sys.path.insert(1, "vqe/qiskit")
import vqe_benchmark
vqe_num_shots=4098
vqe_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits,
                max_circuits=max_circuits, num_shots=vqe_num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# VQE Simulation (1) Benchmark Program - Qiskit
# ... execution starting at Nov 02, 2023 17:08:13 UTC
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Executing [3] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 5, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 76, 0.533, 56.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.668, 2.153, 0.057 secs
# Average Transpiling, Validating, Running Times for group 4 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.85, 0.818
#
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 10, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 341, 0.63, 272.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 1.076, 7.686, 0.151 secs
# Average Transpiling, Validating, Running Times for group 6 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.424, 0.383
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 26, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 1543, 0.692, 1280.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.773, 9.479, 0.768 secs
# Average Transpiling, Validating, Running Times for group 8 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.076, 0.02
#
# ... execution complete at Nov 02, 2023 17:08:36 UTC in 22.718 secs
#
# Sample Circuit:
#          ┌─────┐┌────────────────────┐┌────────────────────┐»
# q5545_0: ┤0    ├┤0                   ├┤0                   ├»
#          │     ││                    ││                    │»
# q5545_1: ┤1    ├┤1                   ├┤1                   ├»
#          │  Hf ││  Cluster Op (0, 1) ││  Cluster Op (2, 3) │»
# q5545_2: ┤2    ├┤2                   ├┤2                   ├»
#          │     ││                    ││                    │»
# q5545_3: ┤3    ├┤3                   ├┤3                   ├»
#          └─────┘└────────────────────┘└────────────────────┘»
#  meas: 4/═══════════════════════════════════════════════════»
#                                                             »
# «         ┌──────────────────────────┐ ░ ┌─┐
# «q5545_0: ┤0                         ├─░─┤M├─────────
# «         │                          │ ░ └╥┘┌─┐
# «q5545_1: ┤1                         ├─░──╫─┤M├──────
# «         │  Cluster Op (0, 1, 2, 3) │ ░  ║ └╥┘┌─┐
# «q5545_2: ┤2                         ├─░──╫──╫─┤M├───
# «         │                          │ ░  ║  ║ └╥┘┌─┐
# «q5545_3: ┤3                         ├─░──╫──╫──╫─┤M├
# «         └──────────────────────────┘ ░  ║  ║  ║ └╥┘
# « meas: 4/════════════════════════════════╩══╩══╩══╩═
# «                                         0  1  2  3
#
# Hartree Fock Generator 'Hf' =
#      ┌───┐
# q_0: ┤ X ├
#      └───┘
# q_1: ─────
#      ┌───┐
# q_2: ┤ X ├
#      └───┘
# q_3: ─────
#
#
# Cluster Operator Example 'Cluster Op' =
#      ┌──────────────────────────────────────────────────────────────────────┐
# q_0: ┤0                                                                     ├
#      │                                                                      │
# q_1: ┤1                                                                     ├
#      │  exp(-it (YXXX + XYXX + XXYX + YYYX + XXXY + YYXY + YXYY + XYYY))(1) │
# q_2: ┤2                                                                     ├
#      │                                                                      │
# q_3: ┤3                                                                     ├
#      └──────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ### Shor - Method 1

# %%
import sys
sys.path.insert(1, "shors/qiskit")
import shors_benchmark
shors_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=1, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Shor's Order Finding (1) Benchmark - Qiskit
# Max number of qubits 8 is too low to run method 1 of Shor's Order Finding

# %% [markdown]
# ### Shor - Method 2

# %%
import sys
sys.path.insert(1, "shors/qiskit")
import shors_benchmark
shors_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=1, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Shor's Order Finding (2) Benchmark - Qiskit
# ... execution starting at Nov 02, 2023 17:08:46 UTC
# ************
# Executing [1] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 881, 0.527
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 2752, 0.413, 1632.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.992, 18.693, 15.853 secs
# Average Transpiling, Validating, Running Times for group 7 = 0.001, 0.001, 0.001 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.19, 0.075
#
# ... execution complete at Nov 02, 2023 17:09:09 UTC in 23.495 secs
#
# Sample Circuit:
#                ░  ┌───┐ ┌───┐┌──────────┐┌──────┐┌───┐┌─┐┌─┐ ░  ┌───┐ ┌───┐»
#   q5744: ──────░──┤ X ├─┤ H ├┤0         ├┤ P(0) ├┤ H ├┤M├┤M├─░──┤ X ├─┤ H ├»
#          ┌───┐ ░  └─╥─┘ └───┘│          │└──╥───┘└───┘└╥┘└╥┘ ░  └─╥─┘ └───┘»
# q5745_0: ┤ X ├─░────╫────────┤1         ├───╫──────────╫──╫──░────╫────────»
#          └───┘ ░    ║        │          │   ║          ║  ║  ░    ║        »
# q5745_1: ──────░────╫────────┤2         ├───╫──────────╫──╫──░────╫────────»
#                ░    ║        │          │   ║          ║  ║  ░    ║        »
# q5746_0: ──────░────╫────────┤3 C-U^256 ├───╫──────────╫──╫──░────╫────────»
#                ░    ║        │          │   ║          ║  ║  ░    ║        »
# q5746_1: ──────░────╫────────┤4         ├───╫──────────╫──╫──░────╫────────»
#                ░    ║        │          │   ║          ║  ║  ░    ║        »
# q5746_2: ──────░────╫────────┤5         ├───╫──────────╫──╫──░────╫────────»
#                ░    ║        │          │   ║          ║  ║  ░    ║        »
# q5746_3: ──────░────╫────────┤6         ├───╫──────────╫──╫──░────╫────────»
#                ░    ║        └──────────┘┌──╨──┐       ║  ║  ░    ║        »
#  c223: 4/═══════════╬════════════════════╡ 0x0 ╞═══════╩══╬═══════╬════════»
#                  ┌──╨──┐                 └─────┘       0  ║    ┌──╨──┐     »
#  c224: 1/════════╡ 0x1 ╞══════════════════════════════════╩════╡ 0x1 ╞═════»
#                  └─────┘                                  0    └─────┘     »
# «         ┌─────────┐┌──────┐┌────────┐┌───┐┌─┐┌─┐ ░  ┌───┐ ┌───┐┌────────┐»
# «  q5744: ┤0        ├┤ P(0) ├┤ P(π/2) ├┤ H ├┤M├┤M├─░──┤ X ├─┤ H ├┤0       ├»
# «         │         │└──╥───┘└───╥────┘└───┘└╥┘└╥┘ ░  └─╥─┘ └───┘│        │»
# «q5745_0: ┤1        ├───╫────────╫───────────╫──╫──░────╫────────┤1       ├»
# «         │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q5745_1: ┤2        ├───╫────────╫───────────╫──╫──░────╫────────┤2       ├»
# «         │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q5746_0: ┤3 C-U^16 ├───╫────────╫───────────╫──╫──░────╫────────┤3 C-U^4 ├»
# «         │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q5746_1: ┤4        ├───╫────────╫───────────╫──╫──░────╫────────┤4       ├»
# «         │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q5746_2: ┤5        ├───╫────────╫───────────╫──╫──░────╫────────┤5       ├»
# «         │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q5746_3: ┤6        ├───╫────────╫───────────╫──╫──░────╫────────┤6       ├»
# «         └─────────┘┌──╨──┐  ┌──╨──┐        ║  ║  ░    ║        └────────┘»
# « c223: 4/═══════════╡ 0x0 ╞══╡ 0x1 ╞════════╩══╬═══════╬══════════════════»
# «                    └─────┘  └─────┘        1  ║    ┌──╨──┐               »
# « c224: 1/══════════════════════════════════════╩════╡ 0x1 ╞═══════════════»
# «                                               0    └─────┘               »
# «         ┌──────┐┌────────┐┌────────┐┌─────────┐┌───┐┌─┐┌─┐ ░  ┌───┐ ┌───┐»
# «  q5744: ┤ P(0) ├┤ P(π/4) ├┤ P(π/2) ├┤ P(3π/4) ├┤ H ├┤M├┤M├─░──┤ X ├─┤ H ├»
# «         └──╥───┘└───╥────┘└───╥────┘└────╥────┘└───┘└╥┘└╥┘ ░  └─╥─┘ └───┘»
# «q5745_0: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «            ║        ║         ║          ║           ║  ║  ░    ║        »
# «q5745_1: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «            ║        ║         ║          ║           ║  ║  ░    ║        »
# «q5746_0: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «            ║        ║         ║          ║           ║  ║  ░    ║        »
# «q5746_1: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «            ║        ║         ║          ║           ║  ║  ░    ║        »
# «q5746_2: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «            ║        ║         ║          ║           ║  ║  ░    ║        »
# «q5746_3: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «         ┌──╨──┐  ┌──╨──┐   ┌──╨──┐    ┌──╨──┐        ║  ║  ░    ║        »
# « c223: 4/╡ 0x0 ╞══╡ 0x1 ╞═══╡ 0x2 ╞════╡ 0x3 ╞════════╩══╬═══════╬════════»
# «         └─────┘  └─────┘   └─────┘    └─────┘        2  ║    ┌──╨──┐     »
# « c224: 1/════════════════════════════════════════════════╩════╡ 0x1 ╞═════»
# «                                                         0    └─────┘     »
# «         ┌────────┐┌──────┐┌────────┐┌────────┐┌─────────┐┌────────┐»
# «  q5744: ┤0       ├┤ P(0) ├┤ P(π/8) ├┤ P(π/4) ├┤ P(3π/8) ├┤ P(π/2) ├»
# «         │        │└──╥───┘└───╥────┘└───╥────┘└────╥────┘└───╥────┘»
# «q5745_0: ┤1       ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «         │        │   ║        ║         ║          ║         ║     »
# «q5745_1: ┤2       ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «         │        │   ║        ║         ║          ║         ║     »
# «q5746_0: ┤3 C-U^2 ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «         │        │   ║        ║         ║          ║         ║     »
# «q5746_1: ┤4       ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «         │        │   ║        ║         ║          ║         ║     »
# «q5746_2: ┤5       ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «         │        │   ║        ║         ║          ║         ║     »
# «q5746_3: ┤6       ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «         └────────┘┌──╨──┐  ┌──╨──┐   ┌──╨──┐    ┌──╨──┐   ┌──╨──┐  »
# « c223: 4/══════════╡ 0x0 ╞══╡ 0x1 ╞═══╡ 0x2 ╞════╡ 0x3 ╞═══╡ 0x4 ╞══»
# «                   └─────┘  └─────┘   └─────┘    └─────┘   └─────┘  »
# « c224: 1/═══════════════════════════════════════════════════════════»
# «                                                                    »
# «         ┌─────────┐┌─────────┐┌─────────┐┌───┐┌─┐┌─┐
# «  q5744: ┤ P(5π/8) ├┤ P(3π/4) ├┤ P(7π/8) ├┤ H ├┤M├┤M├
# «         └────╥────┘└────╥────┘└────╥────┘└───┘└╥┘└╥┘
# «q5745_0: ─────╫──────────╫──────────╫───────────╫──╫─
# «              ║          ║          ║           ║  ║
# «q5745_1: ─────╫──────────╫──────────╫───────────╫──╫─
# «              ║          ║          ║           ║  ║
# «q5746_0: ─────╫──────────╫──────────╫───────────╫──╫─
# «              ║          ║          ║           ║  ║
# «q5746_1: ─────╫──────────╫──────────╫───────────╫──╫─
# «              ║          ║          ║           ║  ║
# «q5746_2: ─────╫──────────╫──────────╫───────────╫──╫─
# «              ║          ║          ║           ║  ║
# «q5746_3: ─────╫──────────╫──────────╫───────────╫──╫─
# «           ┌──╨──┐    ┌──╨──┐    ┌──╨──┐        ║  ║
# « c223: 4/══╡ 0x5 ╞════╡ 0x6 ╞════╡ 0x7 ╞════════╩══╬═
# «           └─────┘    └─────┘    └─────┘        3  ║
# « c224: 1/══════════════════════════════════════════╩═
# «                                                   0
#
# Controlled Ua Operator 'cUa' =
#          ┌─────────────┐      ┌─────────────────┐
#   q5879: ┤0            ├─■──■─┤0                ├
#          │             │ │  │ │                 │
# q5880_0: ┤1            ├─X──┼─┤1                ├
#          │             │ │  │ │                 │
# q5880_1: ┤2            ├─┼──X─┤2                ├
#          │             │ │  │ │                 │
# q5881_0: ┤3 cMULTamodN ├─X──┼─┤3 inv_cMULTamodN ├
#          │             │    │ │                 │
# q5881_1: ┤4            ├────X─┤4                ├
#          │             │      │                 │
# q5882_0: ┤5            ├──────┤5                ├
#          │             │      │                 │
# q5882_1: ┤6            ├──────┤6                ├
#          └─────────────┘      └─────────────────┘
#
# Controlled Multiplier Operator 'cMULTamodN' =
#                  ┌─────────────┐┌─────────────┐
#   q5903: ────────┤0            ├┤0            ├────────────
#                  │             ││             │
# q5904_0: ────────┤1            ├┤             ├────────────
#                  │             ││             │
# q5904_1: ────────┤             ├┤1            ├────────────
#          ┌──────┐│             ││             │┌──────────┐
# q5905_0: ┤0     ├┤2 ccφADDmodN ├┤2 ccφADDmodN ├┤0         ├
#          │      ││             ││             ││          │
# q5905_1: ┤1 qft ├┤3            ├┤3            ├┤1 inv_qft ├
#          │      ││             ││             ││          │
# q5905_2: ┤2     ├┤4            ├┤4            ├┤2         ├
#          └──────┘│             ││             │└──────────┘
#   q5906: ────────┤5            ├┤5            ├────────────
#                  └─────────────┘└─────────────┘
#
# Controlled Modular Adder Operator 'ccphiamodN' =
#                                                                              »
# q5915_0: ────■────────────────────────────────────────────────────────■──────»
#              │                                                        │      »
# q5915_1: ────■────────────────────────────────────────────────────────■──────»
#          ┌───┴───┐┌───────────┐┌──────────┐     ┌──────┐┌───────┐┌────┴─────┐»
# q5916_0: ┤0      ├┤0          ├┤0         ├─────┤0     ├┤0      ├┤0         ├»
#          │       ││           ││          │     │      ││       ││          │»
# q5916_1: ┤1 φADD ├┤1 inv_φADD ├┤1 inv_qft ├─────┤1 qft ├┤1 φADD ├┤1 φADD_dg ├»
#          │       ││           ││          │     │      ││       ││          │»
# q5916_2: ┤2      ├┤2          ├┤2         ├──■──┤2     ├┤2      ├┤2         ├»
#          └───────┘└───────────┘└──────────┘┌─┴─┐└──────┘└───┬───┘└──────────┘»
#   q5917: ──────────────────────────────────┤ X ├────────────■────────────────»
#                                            └───┘                             »
# «
# «q5915_0: ───────────────────────────────────────■────
# «                                                │
# «q5915_1: ───────────────────────────────────────■────
# «         ┌──────────┐               ┌──────┐┌───┴───┐
# «q5916_0: ┤0         ├───────────────┤0     ├┤0      ├
# «         │          │               │      ││       │
# «q5916_1: ┤1 inv_qft ├───────────────┤1 qft ├┤1 φADD ├
# «         │          │┌───┐     ┌───┐│      ││       │
# «q5916_2: ┤2         ├┤ X ├──■──┤ X ├┤2     ├┤2      ├
# «         └──────────┘└───┘┌─┴─┐└───┘└──────┘└───────┘
# «  q5917: ─────────────────┤ X ├──────────────────────
# «                          └───┘
#
# Phi Adder Operator 'φADD' =
#        ┌──────┐
# q_0: ──┤ P(π) ├─
#      ┌─┴──────┴┐
# q_1: ┤ P(3π/2) ├
#      ├─────────┤
# q_2: ┤ P(3π/4) ├
#      └─────────┘
#
# QFT Circuit =
#                ░                  ░                       ┌───┐ ░
# q5923_0: ──────░──────────────────░──────■──────────■─────┤ H ├─░─
#                ░            ┌───┐ ░      │     ┌────┴────┐└───┘ ░
# q5923_1: ──────░──────■─────┤ H ├─░──────┼─────┤ Rz(π/2) ├──────░─
#          ┌───┐ ░ ┌────┴────┐└───┘ ░ ┌────┴────┐└─────────┘      ░
# q5923_2: ┤ H ├─░─┤ Rz(π/2) ├──────░─┤ Rz(π/4) ├─────────────────░─
#          └───┘ ░ └─────────┘      ░ └─────────┘                 ░

# %% [markdown]
# ### Combined Benchmark Results

# %%
import sys
sys.path.insert(1, "_common")
import metrics

# metrics.depth_base = 2
# metrics.QV = 0
# apps = [ "Hidden Shift", "Grover's Search", "Quantum Fourier Transform (1)", "Hamiltonian Simulation" ]
# backend_id='qasm_simulator'

metrics.plot_all_app_metrics(backend_id, do_all_plots=False, include_apps=None)
